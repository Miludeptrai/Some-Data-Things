# %% [markdown]
# <h1><b>HW1: Thu thập và tiền xử lý dữ liệu</b></h1>
#
# Họ tên: Nguyễn Tấn Sơn
#
# MSSV: 20120565
#
# <hr />
#
# <h2><b>Cách làm và nộp bài</b></h2>
# <b>Cách làm bài</b>
#
# Các bạn sẽ làm trực tiếp trên file notebook này. Đầu tiên, bạn điền họ tên và MSSV của mình ở bên trên. Trong file, bạn sẽ làm ở những phần có ghi là:
#
# <i style="background-color:tomato"><FONT COLOR="green"># YOUR CODE HERE</FONT></i>
#
# <FONT COLOR="green">raise</FONT> NotImplementedError()
#
# Tất nhiên, khi làm bạn sẽ xóa dòng <b>raise NotImplementedError()</b> đi. Đối với những phần yêu cầu làm thì thường ở ngay phía dưới sẽ có một (hoặc một số) cell chứa các bộ test để giúp bạn biết đã code đúng hay chưa. Nếu chạy cell này không có lỗi gì thì có nghĩa là qua được các bộ test và ngược lại, nếu không qua được test thì là code sai, nhưng nếu qua được test thì chưa chắc đã đúng.
# </br></br>
# Trong khi làm bài, bạn có thể cho in ra màn hình, tạo thêm các cell để test. Tuy nhiên, khi nộp bài thì code của các bạn sẽ được chạy lại, do đó phải xóa các cell mà bạn đã tạo ra trước đó đi. Ngoài ra, bạn lưu ý là tuyệt đối không được tự tiện xóa các cell hay sửa code của Thầy (trừ những chỗ được phép sửa như đã đề cập ở trên).
# </br></br>
# Trong khi làm bài, thương xuyên lưu lại bài của bạn để tránh mất mát thông tin. Ngoài ra, chúng ta cần hết sức lưu ý là việc đạo văn là bị nghiêm cấm và sẽ bị xử lý đối với các bài làm giống nhau. Mục tiêu chính của chúng ta là học một cách chân thật, các bạn có thể tham khảo ý tưởng từ bạn bè của bạn hay từ các nguồn tham khảo khác trên mạng. Tuy nhiên, phần bài làm cuối cùng vẫn phải là của bạn dựa trên những sự hiểu biết thực sự. Khi tham khảo các nguồn trên mạng thì bạn cũng nên ghi rõ nguồn đó trong bài làm của mình. <font color='red'>Trong trường hợp các bạn vi phạm những điều mình đã đề cập ở trên thì sẽ bị 0 điểm cho toàn bộ môn học này.</font>
#
# <h5><b>Cách nộp bài</h5></b>
#
# Khi chấm bài, mình sẽ chọn Kernel - Restart & Run All để chạy lại toàn bộ code của các bạn từ ban đầu trên google colab. Do đó, để đảm bảo code các bạn không bị lỗi, các bạn nên chạy thử như mình chạy để đảm bảo mọi thứ diễn ra như mong đợi.
#
# Sau đó, bạn tạo thư mục nộp bài theo các yêu cầu sau:
# * Đầu tiên, các bạn tạo một thư mục MSSV (vd, nếu bạn có MSSV là 123456 thì bạn đặt tên thư mục là 123456)
# * Trong thư mục, MSSV vừa tạo, bạn bỏ file notebook bài làm của bạn vào cùng với file project được tạo bởi thư viện scrapy (file project khi tạo này các bạn có thể đặt bất kỳ tên gì)
# * Cuối cùng, bạn nén thư mục MSSV này lại và nộp ở link trên moodle. Đuôi của file nén phải là .zip (chứ không được .rar hay gì khác).
#
# <font color='red'>Bạn lưu ý tuân thủ chính xác qui định nộp bài ở trên, nếu nộp sai quy định sẽ bị trừ nửa số điểm cho bài làm của mình.</font>
# </br></br>
# <hr />
# </br>
# <h2><b>Import</b></h2>
#
# Trong bài thực hành này vì dữ liệu thu thập của chúng ta sẽ rất lớn, nên mình sẽ giúp các bạn thu thập dữ liệu được nhanh chóng bằng cách sử dụng một thư viện có tên scrapy. Vì thư viện này không có sẵn nên các bạn cần cài đặt trước khi sử dụng.

# %%
#cd 20120565
# Out:
# C:\Users\MILU\PycharmProjects\pythonProject\khdl\20120565

# %%
# !pip install scrapy
# !pip install spider3
# Out:
# Requirement already satisfied: scrapy in c:\users\milu\pycharmprojects\pythonproject\lib\site-packages (2.7.0)
# Requirement already satisfied: queuelib>=1.4.2 in c:\users\milu\pycharmprojects\pythonproject\lib\site-packages (from scrapy) (1.6.2)
# Requirement already satisfied: protego>=0.1.15 in c:\users\milu\pycharmprojects\pythonproject\lib\site-packages (from scrapy) (0.2.1)
# Requirement already satisfied: pyOpenSSL>=21.0.0 in c:\users\milu\pycharmprojects\pythonproject\lib\site-packages (from scrapy) (22.1.0)
# Requirement already satisfied: zope.interface>=5.1.0 in c:\users\milu\pycharmprojects\pythonproject\lib\site-packages (from scrapy) (5.4.0)
# Requirement already satisfied: lxml>=4.3.0 in c:\users\milu\pycharmprojects\pythonproject\lib\site-packages (from scrapy) (4.9.1)
# Requirement already satisfied: itemadapter>=0.1.0 in c:\users\milu\pycharmprojects\pythonproject\lib\site-packages (from scrapy) (0.7.0)
# Requirement already satisfied: w3lib>=1.17.0 in c:\users\milu\pycharmprojects\pythonproject\lib\site-packages (from scrapy) (2.0.1)
# Requirement already satisfied: PyDispatcher>=2.0.5 in c:\users\milu\pycharmprojects\pythonproject\lib\site-packages (from scrapy) (2.0.6)
# Requirement already satisfied: cssselect>=0.9.1 in c:\users\milu\pycharmprojects\pythonproject\lib\site-packages (from scrapy) (1.1.0)
# Requirement already satisfied: setuptools in c:\users\milu\pycharmprojects\pythonproject\lib\site-packages (from scrapy) (59.6.0)
# Requirement already satisfied: service-identity>=18.1.0 in c:\users\milu\pycharmprojects\pythonproject\lib\site-packages (from scrapy) (21.1.0)
# Requirement already satisfied: cryptography>=3.3 in c:\users\milu\pycharmprojects\pythonproject\lib\site-packages (from scrapy) (38.0.1)
# Requirement already satisfied: itemloaders>=1.0.1 in c:\users\milu\pycharmprojects\pythonproject\lib\site-packages (from scrapy) (1.0.6)
# Requirement already satisfied: Twisted>=18.9.0 in c:\users\milu\pycharmprojects\pythonproject\lib\site-packages (from scrapy) (22.8.0)
# Requirement already satisfied: parsel>=1.5.0 in c:\users\milu\pycharmprojects\pythonproject\lib\site-packages (from scrapy) (1.6.0)
# Requirement already satisfied: packaging in c:\users\milu\pycharmprojects\pythonproject\lib\site-packages (from scrapy) (21.3)
# Requirement already satisfied: tldextract in c:\users\milu\pycharmprojects\pythonproject\lib\site-packages (from scrapy) (3.4.0)
# Requirement already satisfied: cffi>=1.12 in c:\users\milu\pycharmprojects\pythonproject\lib\site-packages (from cryptography>=3.3->scrapy) (1.15.1)
# Requirement already satisfied: jmespath>=0.9.5 in c:\users\milu\pycharmprojects\pythonproject\lib\site-packages (from itemloaders>=1.0.1->scrapy) (1.0.1)
# Requirement already satisfied: six>=1.6.0 in c:\users\milu\pycharmprojects\pythonproject\lib\site-packages (from parsel>=1.5.0->scrapy) (1.16.0)
# Requirement already satisfied: pyasn1 in c:\users\milu\pycharmprojects\pythonproject\lib\site-packages (from service-identity>=18.1.0->scrapy) (0.4.8)
# Requirement already satisfied: pyasn1-modules in c:\users\milu\pycharmprojects\pythonproject\lib\site-packages (from service-identity>=18.1.0->scrapy) (0.2.8)
# Requirement already satisfied: attrs>=19.1.0 in c:\users\milu\pycharmprojects\pythonproject\lib\site-packages (from service-identity>=18.1.0->scrapy) (22.1.0)
# Requirement already satisfied: twisted-iocpsupport<2,>=1.0.2 in c:\users\milu\pycharmprojects\pythonproject\lib\site-packages (from Twisted>=18.9.0->scrapy) (1.0.2)
# Requirement already satisfied: typing-extensions>=3.6.5 in c:\users\milu\pycharmprojects\pythonproject\lib\site-packages (from Twisted>=18.9.0->scrapy) (4.0.0)
# Requirement already satisfied: hyperlink>=17.1.1 in c:\users\milu\pycharmprojects\pythonproject\lib\site-packages (from Twisted>=18.9.0->scrapy) (21.0.0)
# Requirement already satisfied: Automat>=0.8.0 in c:\users\milu\pycharmprojects\pythonproject\lib\site-packages (from Twisted>=18.9.0->scrapy) (20.2.0)
# Requirement already satisfied: incremental>=21.3.0 in c:\users\milu\pycharmprojects\pythonproject\lib\site-packages (from Twisted>=18.9.0->scrapy) (22.10.0)
# Requirement already satisfied: constantly>=15.1 in c:\users\milu\pycharmprojects\pythonproject\lib\site-packages (from Twisted>=18.9.0->scrapy) (15.1.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\milu\pycharmprojects\pythonproject\lib\site-packages (from packaging->scrapy) (2.4.7)
# Requirement already satisfied: filelock>=3.0.8 in c:\users\milu\pycharmprojects\pythonproject\lib\site-packages (from tldextract->scrapy) (3.8.0)
# Requirement already satisfied: requests-file>=1.4 in c:\users\milu\pycharmprojects\pythonproject\lib\site-packages (from tldextract->scrapy) (1.5.1)
# Requirement already satisfied: idna in c:\users\milu\pycharmprojects\pythonproject\lib\site-packages (from tldextract->scrapy) (3.3)
# Requirement already satisfied: requests>=2.1.0 in c:\users\milu\pycharmprojects\pythonproject\lib\site-packages (from tldextract->scrapy) (2.26.0)
# Requirement already satisfied: pycparser in c:\users\milu\pycharmprojects\pythonproject\lib\site-packages (from cffi>=1.12->cryptography>=3.3->scrapy) (2.21)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\milu\pycharmprojects\pythonproject\lib\site-packages (from requests>=2.1.0->tldextract->scrapy) (1.26.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\milu\pycharmprojects\pythonproject\lib\site-packages (from requests>=2.1.0->tldextract->scrapy) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\milu\pycharmprojects\pythonproject\lib\site-packages (from requests>=2.1.0->tldextract->scrapy) (2021.10.8)
# WARNING: You are using pip version 21.3.1; however, version 22.3 is available.
# You should consider upgrading via the 'c:\users\milu\pycharmprojects\pythonproject\scripts\python.exe -m pip install --upgrade pip' command.
# Requirement already satisfied: spider3 in c:\users\milu\pycharmprojects\pythonproject\lib\site-packages (1.0.2)
# WARNING: You are using pip version 21.3.1; however, version 22.3 is available.
# You should consider upgrading via the 'c:\users\milu\pycharmprojects\pythonproject\scripts\python.exe -m pip install --upgrade pip' command.

# %%
import json
import re
import pandas as pd
import scrapy
import os
from pandas.testing import assert_frame_equal # to compare two dataframes
# YOUR CODE HERE (OPTION) 
# Nếu cần các thư viện khác thì bạn có thể import thêm tại đây

# %% [markdown]
# Như bạn đã biết, World Cup là một giải bóng đá lớn nhất thế giới được tổ chức mỗi 4 năm 1 lần. Vì cuối tháng 11 này kỳ World Cup 2022 sẽ diễn ra, do đó ở Lab 1 này, chúng ta sẽ khởi động môn học bằng việc thu thập dữ liệu của các cầu thủ bóng đá. <b>SoFIFA</b> (https://sofifa.com/) là một trang web lưu trữ dữ liệu của các cầu thủ trong trò chơi bóng đá nổi tiếng FIFA 23 mà có các chỉ số phản ánh gần đúng với phong độ của các cầu thủ bóng đá ngoài đời. Trong phần này, nhiệm vụ đầu tiên của bạn là sẽ cần thu thập ID của các cầu thủ. Mình có check "Terms of Service" của SoFIFA thì không thấy có mục nào nói là cấm parse HTML, vì vậy với mục đích học thì chắc là không có vấn đề gì lớn, miễn là chương trình của bạn đừng "hit" trang web quá nhiều lần trong một khoảng thời gian ngắn thì sẽ không có vấn đề gì.
# </br></br>
# Công việc cụ thể của bạn ở phần đầu tiên này là sẽ cần viết class <b>collect_player_url()</b> ở bên dưới. Vì dữ liệu lúc sau các bạn cần thu thập sẽ rất lớn nên ở đây, chúng ta sẽ xài một thư viên có tên scrapy để có thể thu thập dữ liệu lớn được nhanh chóng hơn. Về cách sử dụng thư viện này thì bạn có thể tham khảo thêm tại trang web sau: https://docs.scrapy.org/en/latest/intro/tutorial.html.
# </br></br>
# <h2><b>Tạo một project mới với scrapy</b><h2>
#
# Để sử dụng thư viện scrapy sau khi cài đặt xong, các bạn sẽ gọi câu lệnh như bên dưới để bắt đầu tạo một project mới với scrapy với tên gọi là <b>"fifa_crawler"</b>.

# %%
# !scrapy startproject fifa_crawler
# Out:
# New Scrapy project 'fifa_crawler', using template directory 'C:\Users\MILU\PycharmProjects\pythonProject\lib\site-packages\scrapy\templates\project', created in:
#     C:\Users\MILU\PycharmProjects\pythonProject\khdl\20120565\fifa_crawler
#
# You can start your first spider with:
#     cd fifa_crawler
#     scrapy genspider example example.com

# %%
# %cd fifa_crawler/fifa_crawler
# Out:
# C:\Users\MILU\PycharmProjects\pythonProject\khdl\20120565\fifa_crawler\fifa_crawler

# %% [markdown]
# Sau khi tạo xong project với scrapy, vì thu thập dữ liệu với thư viện này không cho phép xài notebook trực tiếp nên các bạn sau khi hoàn thành xong class <b>collect_player_url(scrapy.Spider)</b> ở bên dưới, các bạn cần tạo một file có tên <b>collect_players_urls.py</b> vào đường dẫn sau <b>fifa_crawler/fifa_crawler/spiders/collect_players_urls.py</b>. Ngoài ra, để tránh việc <b>hit</b> trang web quá nhiều lần, thay vì thu thập toàn bộ ID các cầu thủ của thì các bạn sẽ chỉ cần thu thập 720 ID cầu thủ. Để cho dễ dàng, mình đã để sẵn 1 đường dẫn urls chứa định dạng offset (từng trang của các cầu thủ với mỗi trang chứa 60 cầu thủ khác nhau) để các bạn có thể dễ dàng chuyển trang mới trong lúc thu thập.

# %%
import scrapy
class MySpider(scrapy.Spider):
    name = 'players_urls'
    custom_settings = { 'CONCURRENT_REQUESTS': '1' }
    def start_requests(self):
        for i in range(int(720/60)):
            yield scrapy.Request(f'https://sofifa.com/players?col=oa&sort=desc&offset={i*60}',self.parse,priority=i)

    def parse(self, response):
        link_player= response.css(".table.table-hover.persist-area > .list > tr > .col-name > a::attr(href)").getall()
        link_player=[i for i in link_player if '?' not in i]
        for i in link_player:
          yield dict.fromkeys(['player_url'],'/'.join(i.split('/')[:3]))

# %% [markdown]
# Sau khi đã viết xong class trên, và đã tạo file <b>collect_players_urls.py</b> trong đường dẫn đã đề cập, bạn sẽ tiến hành gọi lệnh như bên dưới để thu thập ID của các cầu thủ bóng đá và lưu vào một file có tên <b>players_urls.json</b> mà chứa trong thư mục dataset. Thư mục dataset này bạn không cần tạo mà khi thu thập dữ liệu scrapy sẽ tự động tạo cho bạn.

# %%
# !scrapy crawl players_urls -o dataset/players_urls.json
# Out:
# 2022-10-19 20:07:03 [scrapy.utils.log] INFO: Scrapy 2.7.0 started (bot: fifa_crawler)
# 2022-10-19 20:07:03 [scrapy.utils.log] INFO: Versions: lxml 4.9.1.0, libxml2 2.9.12, cssselect 1.1.0, parsel 1.6.0, w3lib 2.0.1, Twisted 22.8.0, Python 3.7.8 (tags/v3.7.8:4b47a5b6ba, Jun 28 2020, 08:53:46) [MSC v.1916 64 bit (AMD64)], pyOpenSSL 22.1.0 (OpenSSL 3.0.5 5 Jul 2022), cryptography 38.0.1, Platform Windows-10-10.0.19041-SP0
# 2022-10-19 20:07:03 [scrapy.crawler] INFO: Overridden settings:
# {'BOT_NAME': 'fifa_crawler',
#  'CONCURRENT_REQUESTS': '1',
#  'NEWSPIDER_MODULE': 'fifa_crawler.spiders',
#  'REQUEST_FINGERPRINTER_IMPLEMENTATION': '2.7',
#  'ROBOTSTXT_OBEY': True,
#  'SPIDER_MODULES': ['fifa_crawler.spiders'],
#  'TWISTED_REACTOR': 'twisted.internet.asyncioreactor.AsyncioSelectorReactor'}
# 2022-10-19 20:07:03 [asyncio] DEBUG: Using selector: SelectSelector
# 2022-10-19 20:07:03 [scrapy.utils.log] DEBUG: Using reactor: twisted.internet.asyncioreactor.AsyncioSelectorReactor
# 2022-10-19 20:07:03 [scrapy.utils.log] DEBUG: Using asyncio event loop: asyncio.windows_events._WindowsSelectorEventLoop
# 2022-10-19 20:07:03 [scrapy.extensions.telnet] INFO: Telnet Password: ca525f4f940395b0
# 2022-10-19 20:07:03 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.feedexport.FeedExporter',
#  'scrapy.extensions.logstats.LogStats']
# 2022-10-19 20:07:03 [scrapy.middleware] INFO: Enabled downloader middlewares:
# ['scrapy.downloadermiddlewares.robotstxt.RobotsTxtMiddleware',
#  'scrapy.downloadermiddlewares.httpauth.HttpAuthMiddleware',
#  'scrapy.downloadermiddlewares.downloadtimeout.DownloadTimeoutMiddleware',
#  'scrapy.downloadermiddlewares.defaultheaders.DefaultHeadersMiddleware',
#  'scrapy.downloadermiddlewares.useragent.UserAgentMiddleware',
#  'scrapy.downloadermiddlewares.retry.RetryMiddleware',
#  'scrapy.downloadermiddlewares.redirect.MetaRefreshMiddleware',
#  'scrapy.downloadermiddlewares.httpcompression.HttpCompressionMiddleware',
#  'scrapy.downloadermiddlewares.redirect.RedirectMiddleware',
#  'scrapy.downloadermiddlewares.cookies.CookiesMiddleware',
#  'scrapy.downloadermiddlewares.httpproxy.HttpProxyMiddleware',
#  'scrapy.downloadermiddlewares.stats.DownloaderStats']
# 2022-10-19 20:07:03 [scrapy.middleware] INFO: Enabled spider middlewares:
# ['scrapy.spidermiddlewares.httperror.HttpErrorMiddleware',
#  'scrapy.spidermiddlewares.offsite.OffsiteMiddleware',
#  'scrapy.spidermiddlewares.referer.RefererMiddleware',
#  'scrapy.spidermiddlewares.urllength.UrlLengthMiddleware',
#  'scrapy.spidermiddlewares.depth.DepthMiddleware']
# 2022-10-19 20:07:03 [scrapy.middleware] INFO: Enabled item pipelines:
# []
# 2022-10-19 20:07:03 [scrapy.core.engine] INFO: Spider opened
# 2022-10-19 20:07:03 [scrapy.extensions.logstats] INFO: Crawled 0 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2022-10-19 20:07:03 [scrapy.extensions.telnet] INFO: Telnet console listening on 127.0.0.1:6023
# 2022-10-19 20:07:04 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://sofifa.com/robots.txt> (referer: None)
# 2022-10-19 20:07:04 [filelock] DEBUG: Attempting to acquire lock 2521486148744 on C:\Users\MILU\PycharmProjects\pythonProject\lib\site-packages\tldextract\.suffix_cache/publicsuffix.org-tlds\de84b5ca2167d4c83e38fb162f2e8738.tldextract.json.lock
# 2022-10-19 20:07:04 [filelock] DEBUG: Lock 2521486148744 acquired on C:\Users\MILU\PycharmProjects\pythonProject\lib\site-packages\tldextract\.suffix_cache/publicsuffix.org-tlds\de84b5ca2167d4c83e38fb162f2e8738.tldextract.json.lock
# 2022-10-19 20:07:04 [filelock] DEBUG: Attempting to release lock 2521486148744 on C:\Users\MILU\PycharmProjects\pythonProject\lib\site-packages\tldextract\.suffix_cache/publicsuffix.org-tlds\de84b5ca2167d4c83e38fb162f2e8738.tldextract.json.lock
# 2022-10-19 20:07:04 [filelock] DEBUG: Lock 2521486148744 released on C:\Users\MILU\PycharmProjects\pythonProject\lib\site-packages\tldextract\.suffix_cache/publicsuffix.org-tlds\de84b5ca2167d4c83e38fb162f2e8738.tldextract.json.lock
# 2022-10-19 20:07:04 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://sofifa.com/players?col=oa&sort=desc&offset=0> (referer: None)
# 2022-10-19 20:07:04 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=0>
#
# {'player_url': '/player/231747'}
# 2022-10-19 20:07:04 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=0>
#
# {'player_url': '/player/192985'}
# 2022-10-19 20:07:04 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=0>
#
# {'player_url': '/player/188545'}
# 2022-10-19 20:07:04 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=0>
#
# {'player_url': '/player/165153'}
# 2022-10-19 20:07:04 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=0>
#
# {'player_url': '/player/158023'}
# 2022-10-19 20:07:04 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=0>
#
# {'player_url': '/player/209331'}
# 2022-10-19 20:07:04 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=0>
#
# {'player_url': '/player/203376'}
# 2022-10-19 20:07:04 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=0>
#
# {'player_url': '/player/192119'}
# 2022-10-19 20:07:04 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=0>
#
# {'player_url': '/player/167495'}
# 2022-10-19 20:07:04 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=0>
#
# {'player_url': '/player/20801'}
# 2022-10-19 20:07:04 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=0>
#
# {'player_url': '/player/215914'}
# 2022-10-19 20:07:04 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=0>
#
# {'player_url': '/player/212831'}
# 2022-10-19 20:07:04 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=0>
#
# {'player_url': '/player/212622'}
# 2022-10-19 20:07:04 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=0>
#
# {'player_url': '/player/210257'}
# 2022-10-19 20:07:04 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=0>
#
# {'player_url': '/player/208722'}
# 2022-10-19 20:07:04 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=0>
#
# {'player_url': '/player/202126'}
# 2022-10-19 20:07:04 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=0>
#
# {'player_url': '/player/200389'}
# 2022-10-19 20:07:04 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=0>
#
# {'player_url': '/player/200145'}
# 2022-10-19 20:07:04 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=0>
#
# {'player_url': '/player/200104'}
# 2022-10-19 20:07:04 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=0>
#
# {'player_url': '/player/190871'}
# 2022-10-19 20:07:04 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=0>
#
# {'player_url': '/player/239818'}
# 2022-10-19 20:07:04 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=0>
#
# {'player_url': '/player/239085'}
# 2022-10-19 20:07:04 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=0>
#
# {'player_url': '/player/230621'}
# 2022-10-19 20:07:04 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=0>
#
# {'player_url': '/player/218667'}
# 2022-10-19 20:07:04 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=0>
#
# {'player_url': '/player/210514'}
# 2022-10-19 20:07:04 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=0>
#
# {'player_url': '/player/207865'}
# 2022-10-19 20:07:04 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=0>
#
# {'player_url': '/player/193041'}
# 2022-10-19 20:07:04 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=0>
#
# {'player_url': '/player/192448'}
# 2022-10-19 20:07:04 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=0>
#
# {'player_url': '/player/182521'}
# 2022-10-19 20:07:04 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=0>
#
# {'player_url': '/player/177003'}
# 2022-10-19 20:07:04 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=0>
#
# {'player_url': '/player/231866'}
# 2022-10-19 20:07:04 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=0>
#
# {'player_url': '/player/231281'}
# 2022-10-19 20:07:04 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=0>
#
# {'player_url': '/player/228702'}
# 2022-10-19 20:07:04 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=0>
#
# {'player_url': '/player/216267'}
# 2022-10-19 20:07:04 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=0>
#
# {'player_url': '/player/215698'}
# 2022-10-19 20:07:04 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=0>
#
# {'player_url': '/player/209658'}
# 2022-10-19 20:07:04 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=0>
#
# {'player_url': '/player/209499'}
# 2022-10-19 20:07:04 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=0>
#
# {'player_url': '/player/205452'}
# 2022-10-19 20:07:04 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=0>
#
# {'player_url': '/player/201024'}
# 2022-10-19 20:07:04 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=0>
#
# {'player_url': '/player/199556'}
# 2022-10-19 20:07:04 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=0>
#
# {'player_url': '/player/193080'}
# 2022-10-19 20:07:04 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=0>
#
# {'player_url': '/player/189596'}
# 2022-10-19 20:07:04 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=0>
#
# {'player_url': '/player/167948'}
# 2022-10-19 20:07:04 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=0>
#
# {'player_url': '/player/238794'}
# 2022-10-19 20:07:04 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=0>
#
# {'player_url': '/player/234642'}
# 2022-10-19 20:07:04 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=0>
#
# {'player_url': '/player/232411'}
# 2022-10-19 20:07:04 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=0>
#
# {'player_url': '/player/232363'}
# 2022-10-19 20:07:04 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=0>
#
# {'player_url': '/player/231478'}
# 2022-10-19 20:07:04 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=0>
#
# {'player_url': '/player/224232'}
# 2022-10-19 20:07:04 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=0>
#
# {'player_url': '/player/223848'}
# 2022-10-19 20:07:04 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=0>
#
# {'player_url': '/player/216352'}
# 2022-10-19 20:07:04 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=0>
#
# {'player_url': '/player/213345'}
# 2022-10-19 20:07:04 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=0>
#
# {'player_url': '/player/212218'}
# 2022-10-19 20:07:04 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=0>
#
# {'player_url': '/player/212198'}
# 2022-10-19 20:07:04 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=0>
#
# {'player_url': '/player/211110'}
# 2022-10-19 20:07:04 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=0>
#
# {'player_url': '/player/204485'}
# 2022-10-19 20:07:04 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=0>
#
# {'player_url': '/player/202652'}
# 2022-10-19 20:07:04 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=0>
#
# {'player_url': '/player/197445'}
# 2022-10-19 20:07:04 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=0>
#
# {'player_url': '/player/192505'}
# 2022-10-19 20:07:04 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=0>
#
# {'player_url': '/player/192387'}
# 2022-10-19 20:07:04 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://sofifa.com/players?col=oa&sort=desc&offset=60> (referer: None)
# 2022-10-19 20:07:05 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=60>
#
# {'player_url': '/player/189513'}
# 2022-10-19 20:07:05 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=60>
#
# {'player_url': '/player/189509'}
# 2022-10-19 20:07:05 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=60>
#
# {'player_url': '/player/188943'}
# 2022-10-19 20:07:05 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=60>
#
# {'player_url': '/player/186153'}
# 2022-10-19 20:07:05 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=60>
#
# {'player_url': '/player/177683'}
# 2022-10-19 20:07:05 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=60>
#
# {'player_url': '/player/164240'}
# 2022-10-19 20:07:05 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=60>
#
# {'player_url': '/player/251854'}
# 2022-10-19 20:07:05 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=60>
#
# {'player_url': '/player/237692'}
# 2022-10-19 20:07:05 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=60>
#
# {'player_url': '/player/235243'}
# 2022-10-19 20:07:05 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=60>
#
# {'player_url': '/player/234236'}
# 2022-10-19 20:07:05 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=60>
#
# {'player_url': '/player/232656'}
# 2022-10-19 20:07:05 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=60>
#
# {'player_url': '/player/224458'}
# 2022-10-19 20:07:05 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=60>
#
# {'player_url': '/player/224334'}
# 2022-10-19 20:07:05 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=60>
#
# {'player_url': '/player/216594'}
# 2022-10-19 20:07:05 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=60>
#
# {'player_url': '/player/212190'}
# 2022-10-19 20:07:05 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=60>
#
# {'player_url': '/player/208574'}
# 2022-10-19 20:07:05 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=60>
#
# {'player_url': '/player/208418'}
# 2022-10-19 20:07:05 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=60>
#
# {'player_url': '/player/208093'}
# 2022-10-19 20:07:05 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=60>
#
# {'player_url': '/player/205498'}
# 2022-10-19 20:07:05 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=60>
#
# {'player_url': '/player/202556'}
# 2022-10-19 20:07:05 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=60>
#
# {'player_url': '/player/195864'}
# 2022-10-19 20:07:05 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=60>
#
# {'player_url': '/player/192629'}
# 2022-10-19 20:07:05 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=60>
#
# {'player_url': '/player/189511'}
# 2022-10-19 20:07:05 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=60>
#
# {'player_url': '/player/189332'}
# 2022-10-19 20:07:05 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=60>
#
# {'player_url': '/player/188567'}
# 2022-10-19 20:07:05 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=60>
#
# {'player_url': '/player/188377'}
# 2022-10-19 20:07:05 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=60>
#
# {'player_url': '/player/188350'}
# 2022-10-19 20:07:05 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=60>
#
# {'player_url': '/player/186942'}
# 2022-10-19 20:07:05 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=60>
#
# {'player_url': '/player/185122'}
# 2022-10-19 20:07:05 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=60>
#
# {'player_url': '/player/269761'}
# 2022-10-19 20:07:05 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=60>
#
# {'player_url': '/player/252371'}
# 2022-10-19 20:07:05 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=60>
#
# {'player_url': '/player/246430'}
# 2022-10-19 20:07:05 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=60>
#
# {'player_url': '/player/242444'}
# 2022-10-19 20:07:05 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=60>
#
# {'player_url': '/player/241852'}
# 2022-10-19 20:07:05 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=60>
#
# {'player_url': '/player/241721'}
# 2022-10-19 20:07:05 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=60>
#
# {'player_url': '/player/241486'}
# 2022-10-19 20:07:05 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=60>
#
# {'player_url': '/player/241096'}
# 2022-10-19 20:07:05 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=60>
#
# {'player_url': '/player/241084'}
# 2022-10-19 20:07:05 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=60>
#
# {'player_url': '/player/240130'}
# 2022-10-19 20:07:05 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=60>
#
# {'player_url': '/player/239053'}
# 2022-10-19 20:07:05 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=60>
#
# {'player_url': '/player/238074'}
# 2022-10-19 20:07:05 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=60>
#
# {'player_url': '/player/237383'}
# 2022-10-19 20:07:05 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=60>
#
# {'player_url': '/player/235805'}
# 2022-10-19 20:07:05 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=60>
#
# {'player_url': '/player/235790'}
# 2022-10-19 20:07:05 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=60>
#
# {'player_url': '/player/235212'}
# 2022-10-19 20:07:05 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=60>
#
# {'player_url': '/player/234396'}
# 2022-10-19 20:07:05 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=60>
#
# {'player_url': '/player/234378'}
# 2022-10-19 20:07:05 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=60>
#
# {'player_url': '/player/233064'}
# 2022-10-19 20:07:05 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=60>
#
# {'player_url': '/player/233049'}
# 2022-10-19 20:07:05 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=60>
#
# {'player_url': '/player/232756'}
# 2022-10-19 20:07:05 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=60>
#
# {'player_url': '/player/230938'}
# 2022-10-19 20:07:05 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=60>
#
# {'player_url': '/player/230142'}
# 2022-10-19 20:07:05 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=60>
#
# {'player_url': '/player/228251'}
# 2022-10-19 20:07:05 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=60>
#
# {'player_url': '/player/226790'}
# 2022-10-19 20:07:05 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=60>
#
# {'player_url': '/player/226161'}
# 2022-10-19 20:07:05 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=60>
#
# {'player_url': '/player/222665'}
# 2022-10-19 20:07:05 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=60>
#
# {'player_url': '/player/222492'}
# 2022-10-19 20:07:05 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=60>
#
# {'player_url': '/player/220814'}
# 2022-10-19 20:07:05 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=60>
#
# {'player_url': '/player/216393'}
# 2022-10-19 20:07:05 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=60>
#
# {'player_url': '/player/212616'}
# 2022-10-19 20:07:05 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://sofifa.com/players?col=oa&sort=desc&offset=120> (referer: None)
# 2022-10-19 20:07:05 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=120>
#
# {'player_url': '/player/210935'}
# 2022-10-19 20:07:05 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=120>
#
# {'player_url': '/player/209989'}
# 2022-10-19 20:07:05 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=120>
#
# {'player_url': '/player/209981'}
# 2022-10-19 20:07:05 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=120>
#
# {'player_url': '/player/208830'}
# 2022-10-19 20:07:05 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=120>
#
# {'player_url': '/player/208128'}
# 2022-10-19 20:07:05 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=120>
#
# {'player_url': '/player/207410'}
# 2022-10-19 20:07:05 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=120>
#
# {'player_url': '/player/206517'}
# 2022-10-19 20:07:05 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=120>
#
# {'player_url': '/player/206113'}
# 2022-10-19 20:07:05 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=120>
#
# {'player_url': '/player/204963'}
# 2022-10-19 20:07:05 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=120>
#
# {'player_url': '/player/204639'}
# 2022-10-19 20:07:05 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=120>
#
# {'player_url': '/player/202811'}
# 2022-10-19 20:07:05 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=120>
#
# {'player_url': '/player/201535'}
# 2022-10-19 20:07:05 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=120>
#
# {'player_url': '/player/199451'}
# 2022-10-19 20:07:05 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=120>
#
# {'player_url': '/player/198219'}
# 2022-10-19 20:07:05 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=120>
#
# {'player_url': '/player/198176'}
# 2022-10-19 20:07:05 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=120>
#
# {'player_url': '/player/197061'}
# 2022-10-19 20:07:05 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=120>
#
# {'player_url': '/player/192984'}
# 2022-10-19 20:07:05 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=120>
#
# {'player_url': '/player/190286'}
# 2022-10-19 20:07:05 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=120>
#
# {'player_url': '/player/189575'}
# 2022-10-19 20:07:05 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=120>
#
# {'player_url': '/player/186345'}
# 2022-10-19 20:07:05 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=120>
#
# {'player_url': '/player/184344'}
# 2022-10-19 20:07:05 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=120>
#
# {'player_url': '/player/183898'}
# 2022-10-19 20:07:05 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=120>
#
# {'player_url': '/player/183277'}
# 2022-10-19 20:07:05 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=120>
#
# {'player_url': '/player/181458'}
# 2022-10-19 20:07:05 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=120>
#
# {'player_url': '/player/180930'}
# 2022-10-19 20:07:05 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=120>
#
# {'player_url': '/player/178603'}
# 2022-10-19 20:07:05 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=120>
#
# {'player_url': '/player/176580'}
# 2022-10-19 20:07:05 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=120>
#
# {'player_url': '/player/175943'}
# 2022-10-19 20:07:05 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=120>
#
# {'player_url': '/player/162835'}
# 2022-10-19 20:07:05 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=120>
#
# {'player_url': '/player/155862'}
# 2022-10-19 20:07:05 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=120>
#
# {'player_url': '/player/143076'}
# 2022-10-19 20:07:05 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=120>
#
# {'player_url': '/player/138956'}
# 2022-10-19 20:07:05 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=120>
#
# {'player_url': '/player/269760'}
# 2022-10-19 20:07:05 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=120>
#
# {'player_url': '/player/253163'}
# 2022-10-19 20:07:05 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=120>
#
# {'player_url': '/player/242516'}
# 2022-10-19 20:07:05 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=120>
#
# {'player_url': '/player/241464'}
# 2022-10-19 20:07:05 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=120>
#
# {'player_url': '/player/239580'}
# 2022-10-19 20:07:05 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=120>
#
# {'player_url': '/player/235073'}
# 2022-10-19 20:07:05 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=120>
#
# {'player_url': '/player/234153'}
# 2022-10-19 20:07:05 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=120>
#
# {'player_url': '/player/233419'}
# 2022-10-19 20:07:05 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=120>
#
# {'player_url': '/player/232488'}
# 2022-10-19 20:07:05 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=120>
#
# {'player_url': '/player/232293'}
# 2022-10-19 20:07:05 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=120>
#
# {'player_url': '/player/231443'}
# 2022-10-19 20:07:05 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=120>
#
# {'player_url': '/player/230869'}
# 2022-10-19 20:07:05 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=120>
#
# {'player_url': '/player/230666'}
# 2022-10-19 20:07:05 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=120>
#
# {'player_url': '/player/230481'}
# 2022-10-19 20:07:05 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=120>
#
# {'player_url': '/player/228618'}
# 2022-10-19 20:07:05 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=120>
#
# {'player_url': '/player/226271'}
# 2022-10-19 20:07:05 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=120>
#
# {'player_url': '/player/225850'}
# 2022-10-19 20:07:05 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=120>
#
# {'player_url': '/player/225375'}
# 2022-10-19 20:07:05 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=120>
#
# {'player_url': '/player/225193'}
# 2022-10-19 20:07:05 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=120>
#
# {'player_url': '/player/224293'}
# 2022-10-19 20:07:05 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=120>
#
# {'player_url': '/player/220834'}
# 2022-10-19 20:07:05 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=120>
#
# {'player_url': '/player/220697'}
# 2022-10-19 20:07:05 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=120>
#
# {'player_url': '/player/220651'}
# 2022-10-19 20:07:05 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=120>
#
# {'player_url': '/player/219693'}
# 2022-10-19 20:07:05 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=120>
#
# {'player_url': '/player/216460'}
# 2022-10-19 20:07:05 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=120>
#
# {'player_url': '/player/215333'}
# 2022-10-19 20:07:05 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=120>
#
# {'player_url': '/player/214997'}
# 2022-10-19 20:07:05 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=120>
#
# {'player_url': '/player/213648'}
# 2022-10-19 20:07:05 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://sofifa.com/players?col=oa&sort=desc&offset=180> (referer: None)
# 2022-10-19 20:07:05 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=180>
#
# {'player_url': '/player/213565'}
# 2022-10-19 20:07:05 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=180>
#
# {'player_url': '/player/210406'}
# 2022-10-19 20:07:05 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=180>
#
# {'player_url': '/player/210315'}
# 2022-10-19 20:07:05 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=180>
#
# {'player_url': '/player/210243'}
# 2022-10-19 20:07:05 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=180>
#
# {'player_url': '/player/208670'}
# 2022-10-19 20:07:05 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=180>
#
# {'player_url': '/player/203574'}
# 2022-10-19 20:07:05 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=180>
#
# {'player_url': '/player/201942'}
# 2022-10-19 20:07:05 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=180>
#
# {'player_url': '/player/199434'}
# 2022-10-19 20:07:05 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=180>
#
# {'player_url': '/player/198706'}
# 2022-10-19 20:07:05 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=180>
#
# {'player_url': '/player/194765'}
# 2022-10-19 20:07:05 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=180>
#
# {'player_url': '/player/193747'}
# 2022-10-19 20:07:05 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=180>
#
# {'player_url': '/player/193698'}
# 2022-10-19 20:07:05 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=180>
#
# {'player_url': '/player/193082'}
# 2022-10-19 20:07:05 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=180>
#
# {'player_url': '/player/184134'}
# 2022-10-19 20:07:05 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=180>
#
# {'player_url': '/player/183711'}
# 2022-10-19 20:07:05 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=180>
#
# {'player_url': '/player/168542'}
# 2022-10-19 20:07:05 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=180>
#
# {'player_url': '/player/163587'}
# 2022-10-19 20:07:05 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=180>
#
# {'player_url': '/player/152729'}
# 2022-10-19 20:07:05 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=180>
#
# {'player_url': '/player/146536'}
# 2022-10-19 20:07:05 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=180>
#
# {'player_url': '/player/269763'}
# 2022-10-19 20:07:05 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=180>
#
# {'player_url': '/player/256790'}
# 2022-10-19 20:07:05 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=180>
#
# {'player_url': '/player/256630'}
# 2022-10-19 20:07:05 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=180>
#
# {'player_url': '/player/255475'}
# 2022-10-19 20:07:05 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=180>
#
# {'player_url': '/player/253072'}
# 2022-10-19 20:07:05 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=180>
#
# {'player_url': '/player/247819'}
# 2022-10-19 20:07:05 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=180>
#
# {'player_url': '/player/246669'}
# 2022-10-19 20:07:05 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=180>
#
# {'player_url': '/player/244260'}
# 2022-10-19 20:07:05 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=180>
#
# {'player_url': '/player/241637'}
# 2022-10-19 20:07:05 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=180>
#
# {'player_url': '/player/241461'}
# 2022-10-19 20:07:05 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=180>
#
# {'player_url': '/player/236401'}
# 2022-10-19 20:07:05 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=180>
#
# {'player_url': '/player/236276'}
# 2022-10-19 20:07:05 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=180>
#
# {'player_url': '/player/233934'}
# 2022-10-19 20:07:05 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=180>
#
# {'player_url': '/player/233927'}
# 2022-10-19 20:07:05 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=180>
#
# {'player_url': '/player/233096'}
# 2022-10-19 20:07:05 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=180>
#
# {'player_url': '/player/231969'}
# 2022-10-19 20:07:05 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=180>
#
# {'player_url': '/player/231352'}
# 2022-10-19 20:07:05 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=180>
#
# {'player_url': '/player/230375'}
# 2022-10-19 20:07:05 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=180>
#
# {'player_url': '/player/230182'}
# 2022-10-19 20:07:05 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=180>
#
# {'player_url': '/player/229984'}
# 2022-10-19 20:07:05 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=180>
#
# {'player_url': '/player/228941'}
# 2022-10-19 20:07:05 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=180>
#
# {'player_url': '/player/227796'}
# 2022-10-19 20:07:05 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=180>
#
# {'player_url': '/player/227127'}
# 2022-10-19 20:07:05 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=180>
#
# {'player_url': '/player/226754'}
# 2022-10-19 20:07:05 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=180>
#
# {'player_url': '/player/226753'}
# 2022-10-19 20:07:05 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=180>
#
# {'player_url': '/player/226221'}
# 2022-10-19 20:07:05 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=180>
#
# {'player_url': '/player/224411'}
# 2022-10-19 20:07:05 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=180>
#
# {'player_url': '/player/223952'}
# 2022-10-19 20:07:05 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=180>
#
# {'player_url': '/player/223697'}
# 2022-10-19 20:07:05 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=180>
#
# {'player_url': '/player/222077'}
# 2022-10-19 20:07:05 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=180>
#
# {'player_url': '/player/217870'}
# 2022-10-19 20:07:05 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=180>
#
# {'player_url': '/player/216547'}
# 2022-10-19 20:07:05 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=180>
#
# {'player_url': '/player/216354'}
# 2022-10-19 20:07:05 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=180>
#
# {'player_url': '/player/215316'}
# 2022-10-19 20:07:05 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=180>
#
# {'player_url': '/player/213661'}
# 2022-10-19 20:07:05 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=180>
#
# {'player_url': '/player/213331'}
# 2022-10-19 20:07:05 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=180>
#
# {'player_url': '/player/212523'}
# 2022-10-19 20:07:05 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=180>
#
# {'player_url': '/player/212194'}
# 2022-10-19 20:07:05 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=180>
#
# {'player_url': '/player/212188'}
# 2022-10-19 20:07:05 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=180>
#
# {'player_url': '/player/211688'}
# 2022-10-19 20:07:05 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=180>
#
# {'player_url': '/player/210411'}
# 2022-10-19 20:07:06 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://sofifa.com/players?col=oa&sort=desc&offset=240> (referer: None)
# 2022-10-19 20:07:06 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=240>
#
# {'player_url': '/player/210035'}
# 2022-10-19 20:07:06 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=240>
#
# {'player_url': '/player/209889'}
# 2022-10-19 20:07:06 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=240>
#
# {'player_url': '/player/208333'}
# 2022-10-19 20:07:06 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=240>
#
# {'player_url': '/player/207862'}
# 2022-10-19 20:07:06 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=240>
#
# {'player_url': '/player/205693'}
# 2022-10-19 20:07:06 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=240>
#
# {'player_url': '/player/204935'}
# 2022-10-19 20:07:06 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=240>
#
# {'player_url': '/player/204638'}
# 2022-10-19 20:07:06 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=240>
#
# {'player_url': '/player/204525'}
# 2022-10-19 20:07:06 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=240>
#
# {'player_url': '/player/202884'}
# 2022-10-19 20:07:06 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=240>
#
# {'player_url': '/player/202648'}
# 2022-10-19 20:07:06 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=240>
#
# {'player_url': '/player/201455'}
# 2022-10-19 20:07:06 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=240>
#
# {'player_url': '/player/201305'}
# 2022-10-19 20:07:06 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=240>
#
# {'player_url': '/player/200724'}
# 2022-10-19 20:07:06 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=240>
#
# {'player_url': '/player/200610'}
# 2022-10-19 20:07:06 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=240>
#
# {'player_url': '/player/200458'}
# 2022-10-19 20:07:06 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=240>
#
# {'player_url': '/player/200260'}
# 2022-10-19 20:07:06 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=240>
#
# {'player_url': '/player/199845'}
# 2022-10-19 20:07:06 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=240>
#
# {'player_url': '/player/199482'}
# 2022-10-19 20:07:06 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=240>
#
# {'player_url': '/player/199110'}
# 2022-10-19 20:07:06 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=240>
#
# {'player_url': '/player/198717'}
# 2022-10-19 20:07:06 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=240>
#
# {'player_url': '/player/197781'}
# 2022-10-19 20:07:06 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=240>
#
# {'player_url': '/player/197655'}
# 2022-10-19 20:07:06 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=240>
#
# {'player_url': '/player/193474'}
# 2022-10-19 20:07:06 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=240>
#
# {'player_url': '/player/190941'}
# 2022-10-19 20:07:06 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=240>
#
# {'player_url': '/player/190460'}
# 2022-10-19 20:07:06 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=240>
#
# {'player_url': '/player/189242'}
# 2022-10-19 20:07:06 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=240>
#
# {'player_url': '/player/184432'}
# 2022-10-19 20:07:06 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=240>
#
# {'player_url': '/player/184200'}
# 2022-10-19 20:07:06 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=240>
#
# {'player_url': '/player/184087'}
# 2022-10-19 20:07:06 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=240>
#
# {'player_url': '/player/183512'}
# 2022-10-19 20:07:06 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=240>
#
# {'player_url': '/player/179645'}
# 2022-10-19 20:07:06 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=240>
#
# {'player_url': '/player/178509'}
# 2022-10-19 20:07:06 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=240>
#
# {'player_url': '/player/178005'}
# 2022-10-19 20:07:06 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=240>
#
# {'player_url': '/player/177388'}
# 2022-10-19 20:07:06 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=240>
#
# {'player_url': '/player/168651'}
# 2022-10-19 20:07:06 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=240>
#
# {'player_url': '/player/164835'}
# 2022-10-19 20:07:06 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=240>
#
# ...
#
# {'player_url': '/player/202166'}
# 2022-10-19 20:07:08 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=600>
#
# {'player_url': '/player/202048'}
# 2022-10-19 20:07:08 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=600>
#
# {'player_url': '/player/201995'}
# 2022-10-19 20:07:08 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=600>
#
# {'player_url': '/player/201519'}
# 2022-10-19 20:07:08 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=600>
#
# {'player_url': '/player/201119'}
# 2022-10-19 20:07:08 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=600>
#
# {'player_url': '/player/201095'}
# 2022-10-19 20:07:08 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=600>
#
# {'player_url': '/player/199915'}
# 2022-10-19 20:07:08 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=600>
#
# {'player_url': '/player/199641'}
# 2022-10-19 20:07:08 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=600>
#
# {'player_url': '/player/199503'}
# 2022-10-19 20:07:08 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=600>
#
# {'player_url': '/player/199339'}
# 2022-10-19 20:07:08 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=600>
#
# {'player_url': '/player/199254'}
# 2022-10-19 20:07:08 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=600>
#
# {'player_url': '/player/199042'}
# 2022-10-19 20:07:08 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=600>
#
# {'player_url': '/player/198031'}
# 2022-10-19 20:07:08 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=600>
#
# {'player_url': '/player/198009'}
# 2022-10-19 20:07:08 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=600>
#
# {'player_url': '/player/197891'}
# 2022-10-19 20:07:08 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=600>
#
# {'player_url': '/player/196978'}
# 2022-10-19 20:07:08 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=600>
#
# {'player_url': '/player/195861'}
# 2022-10-19 20:07:08 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=600>
#
# {'player_url': '/player/195859'}
# 2022-10-19 20:07:08 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=600>
#
# {'player_url': '/player/193198'}
# 2022-10-19 20:07:08 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=600>
#
# {'player_url': '/player/192638'}
# 2022-10-19 20:07:08 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=600>
#
# {'player_url': '/player/191740'}
# 2022-10-19 20:07:08 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=600>
#
# {'player_url': '/player/191202'}
# 2022-10-19 20:07:08 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=600>
#
# {'player_url': '/player/190815'}
# 2022-10-19 20:07:08 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=600>
#
# {'player_url': '/player/190745'}
# 2022-10-19 20:07:08 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=600>
#
# {'player_url': '/player/190717'}
# 2022-10-19 20:07:08 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=600>
#
# {'player_url': '/player/190674'}
# 2022-10-19 20:07:08 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=600>
#
# {'player_url': '/player/189805'}
# 2022-10-19 20:07:08 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=600>
#
# {'player_url': '/player/189690'}
# 2022-10-19 20:07:08 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=600>
#
# {'player_url': '/player/189505'}
# 2022-10-19 20:07:08 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=600>
#
# {'player_url': '/player/188988'}
# 2022-10-19 20:07:08 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=600>
#
# {'player_url': '/player/187072'}
# 2022-10-19 20:07:08 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=600>
#
# {'player_url': '/player/184941'}
# 2022-10-19 20:07:08 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=600>
#
# {'player_url': '/player/183907'}
# 2022-10-19 20:07:08 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=600>
#
# {'player_url': '/player/183855'}
# 2022-10-19 20:07:08 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://sofifa.com/players?col=oa&sort=desc&offset=660> (referer: None)
# 2022-10-19 20:07:08 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=660>
#
# {'player_url': '/player/183574'}
# 2022-10-19 20:07:08 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=660>
#
# {'player_url': '/player/182494'}
# 2022-10-19 20:07:08 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=660>
#
# {'player_url': '/player/182212'}
# 2022-10-19 20:07:08 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=660>
#
# {'player_url': '/player/178750'}
# 2022-10-19 20:07:08 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=660>
#
# {'player_url': '/player/178224'}
# 2022-10-19 20:07:08 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=660>
#
# {'player_url': '/player/177413'}
# 2022-10-19 20:07:08 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=660>
#
# {'player_url': '/player/173030'}
# 2022-10-19 20:07:08 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=660>
#
# {'player_url': '/player/172522'}
# 2022-10-19 20:07:08 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=660>
#
# {'player_url': '/player/170368'}
# 2022-10-19 20:07:08 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=660>
#
# {'player_url': '/player/169588'}
# 2022-10-19 20:07:08 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=660>
#
# {'player_url': '/player/163705'}
# 2022-10-19 20:07:08 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=660>
#
# {'player_url': '/player/156433'}
# 2022-10-19 20:07:08 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=660>
#
# {'player_url': '/player/146748'}
# 2022-10-19 20:07:08 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=660>
#
# {'player_url': '/player/45186'}
# 2022-10-19 20:07:08 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=660>
#
# {'player_url': '/player/1179'}
# 2022-10-19 20:07:08 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=660>
#
# {'player_url': '/player/269780'}
# 2022-10-19 20:07:08 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=660>
#
# {'player_url': '/player/269775'}
# 2022-10-19 20:07:08 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=660>
#
# {'player_url': '/player/269766'}
# 2022-10-19 20:07:08 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=660>
#
# {'player_url': '/player/262621'}
# 2022-10-19 20:07:08 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=660>
#
# {'player_url': '/player/256612'}
# 2022-10-19 20:07:08 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=660>
#
# {'player_url': '/player/256197'}
# 2022-10-19 20:07:08 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=660>
#
# {'player_url': '/player/255654'}
# 2022-10-19 20:07:08 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=660>
#
# {'player_url': '/player/253109'}
# 2022-10-19 20:07:08 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=660>
#
# {'player_url': '/player/251566'}
# 2022-10-19 20:07:08 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=660>
#
# {'player_url': '/player/251470'}
# 2022-10-19 20:07:08 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=660>
#
# {'player_url': '/player/251116'}
# 2022-10-19 20:07:08 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=660>
#
# {'player_url': '/player/247246'}
# 2022-10-19 20:07:08 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=660>
#
# {'player_url': '/player/247204'}
# 2022-10-19 20:07:08 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=660>
#
# {'player_url': '/player/247131'}
# 2022-10-19 20:07:08 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=660>
#
# {'player_url': '/player/247090'}
# 2022-10-19 20:07:08 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=660>
#
# {'player_url': '/player/246191'}
# 2022-10-19 20:07:08 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=660>
#
# {'player_url': '/player/245235'}
# 2022-10-19 20:07:08 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=660>
#
# {'player_url': '/player/244892'}
# 2022-10-19 20:07:08 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=660>
#
# {'player_url': '/player/244622'}
# 2022-10-19 20:07:08 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=660>
#
# {'player_url': '/player/243854'}
# 2022-10-19 20:07:08 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=660>
#
# {'player_url': '/player/243647'}
# 2022-10-19 20:07:08 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=660>
#
# {'player_url': '/player/243388'}
# 2022-10-19 20:07:08 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=660>
#
# {'player_url': '/player/242664'}
# 2022-10-19 20:07:08 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=660>
#
# {'player_url': '/player/242187'}
# 2022-10-19 20:07:08 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=660>
#
# {'player_url': '/player/242000'}
# 2022-10-19 20:07:08 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=660>
#
# {'player_url': '/player/241727'}
# 2022-10-19 20:07:08 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=660>
#
# {'player_url': '/player/241390'}
# 2022-10-19 20:07:08 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=660>
#
# {'player_url': '/player/241159'}
# 2022-10-19 20:07:08 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=660>
#
# {'player_url': '/player/241095'}
# 2022-10-19 20:07:08 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=660>
#
# {'player_url': '/player/240938'}
# 2022-10-19 20:07:08 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=660>
#
# {'player_url': '/player/240787'}
# 2022-10-19 20:07:08 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=660>
#
# {'player_url': '/player/240740'}
# 2022-10-19 20:07:08 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=660>
#
# {'player_url': '/player/240699'}
# 2022-10-19 20:07:08 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=660>
#
# {'player_url': '/player/240091'}
# 2022-10-19 20:07:08 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=660>
#
# {'player_url': '/player/239901'}
# 2022-10-19 20:07:08 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=660>
#
# {'player_url': '/player/239380'}
# 2022-10-19 20:07:08 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=660>
#
# {'player_url': '/player/239207'}
# 2022-10-19 20:07:08 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=660>
#
# {'player_url': '/player/238616'}
# 2022-10-19 20:07:08 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=660>
#
# {'player_url': '/player/238463'}
# 2022-10-19 20:07:08 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=660>
#
# {'player_url': '/player/236679'}
# 2022-10-19 20:07:08 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=660>
#
# {'player_url': '/player/236610'}
# 2022-10-19 20:07:08 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=660>
#
# {'player_url': '/player/236583'}
# 2022-10-19 20:07:08 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=660>
#
# {'player_url': '/player/236499'}
# 2022-10-19 20:07:08 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=660>
#
# {'player_url': '/player/235619'}
# 2022-10-19 20:07:08 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/players?col=oa&sort=desc&offset=660>
#
# {'player_url': '/player/234612'}
# 2022-10-19 20:07:08 [scrapy.core.engine] INFO: Closing spider (finished)
# 2022-10-19 20:07:08 [scrapy.extensions.feedexport] INFO: Stored json feed (720 items) in: dataset/players_urls.json
# 2022-10-19 20:07:08 [scrapy.statscollectors] INFO: Dumping Scrapy stats:
# {'downloader/request_bytes': 3905,
#  'downloader/request_count': 13,
#  'downloader/request_method_count/GET': 13,
#  'downloader/response_bytes': 1022019,
#  'downloader/response_count': 13,
#  'downloader/response_status_count/200': 13,
#  'elapsed_time_seconds': 5.239676,
#  'feedexport/success_count/FileFeedStorage': 1,
#  'finish_reason': 'finished',
#  'finish_time': datetime.datetime(2022, 10, 19, 13, 7, 8, 853255),
#  'httpcompression/response_bytes': 5442798,
#  'httpcompression/response_count': 13,
#  'item_scraped_count': 720,
#  'log_count/DEBUG': 740,
#  'log_count/INFO': 11,
#  'response_received_count': 13,
#  'robotstxt/request_count': 1,
#  'robotstxt/response_count': 1,
#  'robotstxt/response_status_count/200': 1,
#  'scheduler/dequeued': 12,
#  'scheduler/dequeued/memory': 12,
#  'scheduler/enqueued': 12,
#  'scheduler/enqueued/memory': 12,
#  'start_time': datetime.datetime(2022, 10, 19, 13, 7, 3, 613579)}
# 2022-10-19 20:07:08 [scrapy.core.engine] INFO: Spider closed (finished)

# %% [markdown]
# Sau khi đã có danh sách 720 ID của các cầu thủ đã thu thập từ trang web SoFIFA, bạn sẽ tiến hành thu thập dữ liệu cụ thể của từng cầu thủ ứng với các ID này bằng cách hoàn thành class <b>collect_player_info(scrapy.Spider)</b> như bên dưới. Các bạn cũng lưu ý lại là như mình đã đề cập, việc sử dụng scrapy trực tiếp notebook là không được mà chúng ta sẽ cần tạo tiếp một file mới có tên <b>collect_players_info.py</b> vào cùng đường dẫn như file <b>collect_players_urls.py</b>. Ở đây, cũng để cho tiện thì mình cũng để cho các bạn 1 đường dẫn url mới với ID 231747 ứng với ID đầu tiên mà chúng ta đã thu thập ở bước trước. Nhiệm vụ của các bạn là dựa vào url này để tiếp tục hoàn thành việc parse HTML và thu thập các thông tin chi tiết của ID này (chúng ta cũng làm tương tự cho 719 ID còn lại). Về chi tiết tất cả các dữ liệu các bạn cần thu thập thì mình có để sẵn 1 file test có tên <b>players_info.json</b> là file đã được mình thu thập về thông tin chi tiết của 720 cầu thủ cho các bạn.

# %%
df_test = pd.read_json('./content/players_info.json', encoding='utf-8-sig')
df_test.iloc[0]
# Out:
# id                                                                     231747
# name                                                     Kylian Mbappé Lottin
# primary_position                                                           ST
# positions                                                            [ST, LW]
# age                                                                        23
# birth_date                                                        1998/Dec/20
# height                                                                    182
# weight                                                                     73
# Overall Rating                                                             91
# Potential                                                                  95
# Value                                                                 €190.5M
# Wage                                                                    €230K
# Preferred Foot                                                          Right
# Weak Foot                                                                   4
# Skill Moves                                                                 5
# International Reputation                                                    4
# Work Rate                                                           High/ Low
# Body Type                                                              Unique
# Real Face                                                                 Yes
# Release Clause                                                        €366.7M
# teams                             {' Paris Saint-Germain': 85, ' France': 85}
# attacking                   {'Crossing': 78, 'Finishing': 93, 'HeadingAccu...
# skill                       {'Dribbling': 93, 'Curve': 80, 'FKAccuracy': 6...
# movement                    {'Acceleration': 97, 'SprintSpeed': 97, 'Agili...
# power                       {'ShotPower': 88, 'Jumping': 77, 'Stamina': 87...
# mentality                   {'Aggression': 64, 'Interceptions': 38, 'Posit...
# defending                   {'DefensiveAwareness': 26, 'StandingTackle': 3...
# goalkeeping                 {'GKDiving': 13, 'GKHandling': 5, 'GKKicking':...
# player_traits               [Solid Player, Flair, Speed Dribbler (AI), Out...
# player_specialities         [#Speedster, #Dribbler, #Acrobat, #Clinical Fi...
# Name: 0, dtype: object

# %%
import scrapy
import json

class collect_player_info(scrapy.Spider):
    name = 'players_info'
    custom_settings = { 'CONCURRENT_REQUESTS': '1' }
    url=[]
    def __init__(self):
        players = [{'player_url':''}]
        try:
            with open('./dataset/players_urls.json') as f:
                players = json.load(f)
            player_count = 1

        except IOError:
            print("File not found")
        for i in players:
            self.url = self.url+[i['player_url']]


    def start_requests(self):
        for i in self.url:
            yield scrapy.Request(f'https://sofifa.com{i}',self.parse)

    def parse(self, response):
        def makedict(keys,values,isRemoveSpace=False):
            res={}
            if(len(values)==0):
                return keys
            for key in keys:
                for value in values:
                    if(isRemoveSpace):
                        res[key.replace(" ", "")] = value
                    else:
                        res[key] = value
                    values.remove(value)
                    break
            return res
        def makenumber(i):
            k=i
            for j in range(len(i)):
                if i[j].strip().isnumeric():
                    k[j]=int(i[j].strip())
                else:
                    k[j]=i[j]
            return k
        books={}
        books['id']=response.request.url.split('/')[4]
        books['name']=response.css(".bp3-card.player > .info > h1::text").get()
        books['primary_position']=response.css(".center > .grid > .col.col-4 > .pl > .ellipsis > span::text").get()
        books['positions']=response.css(".meta.ellipsis > span::text").getall()
        books['age'] = response.css(".table.table-hover.persist-area > .list > tr > .col-ae::text").get()
        info=response.css(".info > .meta.ellipsis::text").getall()[::-1][0]
        info=[i for i in info.split(' ') if i!='']
        books['age']=''.join([i for i in info[0] if (i>='0' and i<='9')])
        books['birth_date']=''.join([i for i in '/'.join([info[3],info[1],info[2]]) if ((i != ')') and (i != '(' ) and (i !=','))])
        books['height']=int(''.join([i for i in info[4] if (i>='0' and i<='9')]))
        books['weight'] =int( ''.join([i for i in info[5] if (i >= '0' and i <= '9')]))
        temp=response.xpath('//section[@class="card spacing"]/div/div/span/text()').extract()
        books['Overall Rating'],books['Potential']=[int(i) for i in temp if i.isnumeric()]
        books['Value'], books['Wage']=[i for i in response.xpath('//section[@class="card spacing"]/div/div/text()').extract() if i!=' ']

        curr_selectors=response.xpath('//div[@class="col col-12"]/div[@class="block-quarter"]/div/ul')
        curr_selectors=[scrapy.selector.Selector(text=i) for i in curr_selectors.css('.ellipsis').getall()]
        for i in curr_selectors:
            if (len(i.xpath('//label/text()').extract()) == 0):
                continue
            elif (i.xpath('//label/text()').extract()[0] == ' ' or i.xpath('//label/text()').extract()[0] == '\n'):
                continue
            elif (i.xpath('//label/text()').extract()[0] == 'Position' or i.xpath('//label/text()').extract()[0] == 'ID'):
                continue
            elif (i.xpath('//label/text()').extract()[0] == 'Preferred Foot'):
                books['Preferred Foot'] = i.xpath('//text()').extract()[1]
            elif (i.xpath('//text()').extract_first().strip().isnumeric()):
                books[i.xpath('//label/text()').extract()[0]] = int(i.xpath('//text()').extract_first().strip())
            else:
                books[i.xpath('//label/text()').extract()[0]] = i.xpath('//text()').extract()[::-1][0]

        keys=response.xpath('//div[@class="col col-12"]/div[@class="block-quarter"]/div/h5/a/text()').extract()
        values=[i for i in response.xpath('//div[@class="col col-12"]/div[@class="block-quarter"]/div/ul[@class="ellipsis pl"]/li/span/text()').extract() if i.isnumeric()]
        values = makenumber(values)
        books['teams']=makedict(keys,values)
        curr_selectors = response.xpath('//div[@class="col col-12"]/div[@class="block-quarter"]')
        curr_selectors = [scrapy.selector.Selector(text=i) for i in curr_selectors.css('.card').getall()]
        temp = []
        for i in curr_selectors:
            if (len(i.xpath('//h5/text()').extract()) == 0):
                continue
            elif (i.xpath('//h5/text()').extract()[0] == 'Profile'):
                continue
            elif (i.xpath('//h5/text()').extract()[0] == 'Player Specialities'):
                temp = i

            else:
                keys = i.xpath('//ul/li/span[@role="tooltip"]/text()').extract()
                values = i.css('.bp3-tag::text').getall()
                values = makenumber(values)
                books[i.xpath('//h5/text()').extract()[0].lower()] = makedict(keys, values, isRemoveSpace=True)
        try:
            books['player_traits'] = books.pop('traits')
        except:
            books['player_traits']=[]
        books['player_specialities'] = temp.css('ul > li ::text').getall()
        yield books

# %% [markdown]
# Sau khi đã hoàn thành class ở trên và lưu lại trong file <b>collect_players_info.py</b>, các bạn sẽ tiếp tục chạy câu lệnh bên dưới để thu thập thông tin chi tiết của toàn bộ 720 cầu thủ và xuất ra file <b>players_info.json</b> ở cùng đường dẫn dataset như trên.

# %%
# !scrapy crawl players_info -o dataset/players_info.json
# Out:
# 2022-10-19 20:19:28 [scrapy.utils.log] INFO: Scrapy 2.7.0 started (bot: fifa_crawler)
# 2022-10-19 20:19:28 [scrapy.utils.log] INFO: Versions: lxml 4.9.1.0, libxml2 2.9.12, cssselect 1.1.0, parsel 1.6.0, w3lib 2.0.1, Twisted 22.8.0, Python 3.7.8 (tags/v3.7.8:4b47a5b6ba, Jun 28 2020, 08:53:46) [MSC v.1916 64 bit (AMD64)], pyOpenSSL 22.1.0 (OpenSSL 3.0.5 5 Jul 2022), cryptography 38.0.1, Platform Windows-10-10.0.19041-SP0
# 2022-10-19 20:19:28 [scrapy.crawler] INFO: Overridden settings:
# {'BOT_NAME': 'fifa_crawler',
#  'CONCURRENT_REQUESTS': '1',
#  'NEWSPIDER_MODULE': 'fifa_crawler.spiders',
#  'REQUEST_FINGERPRINTER_IMPLEMENTATION': '2.7',
#  'ROBOTSTXT_OBEY': True,
#  'SPIDER_MODULES': ['fifa_crawler.spiders'],
#  'TWISTED_REACTOR': 'twisted.internet.asyncioreactor.AsyncioSelectorReactor'}
# 2022-10-19 20:19:28 [asyncio] DEBUG: Using selector: SelectSelector
# 2022-10-19 20:19:28 [scrapy.utils.log] DEBUG: Using reactor: twisted.internet.asyncioreactor.AsyncioSelectorReactor
# 2022-10-19 20:19:28 [scrapy.utils.log] DEBUG: Using asyncio event loop: asyncio.windows_events._WindowsSelectorEventLoop
# 2022-10-19 20:19:28 [scrapy.extensions.telnet] INFO: Telnet Password: 32f40bf5e19c49eb
# 2022-10-19 20:19:28 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.feedexport.FeedExporter',
#  'scrapy.extensions.logstats.LogStats']
# 2022-10-19 20:19:28 [scrapy.middleware] INFO: Enabled downloader middlewares:
# ['scrapy.downloadermiddlewares.robotstxt.RobotsTxtMiddleware',
#  'scrapy.downloadermiddlewares.httpauth.HttpAuthMiddleware',
#  'scrapy.downloadermiddlewares.downloadtimeout.DownloadTimeoutMiddleware',
#  'scrapy.downloadermiddlewares.defaultheaders.DefaultHeadersMiddleware',
#  'scrapy.downloadermiddlewares.useragent.UserAgentMiddleware',
#  'scrapy.downloadermiddlewares.retry.RetryMiddleware',
#  'scrapy.downloadermiddlewares.redirect.MetaRefreshMiddleware',
#  'scrapy.downloadermiddlewares.httpcompression.HttpCompressionMiddleware',
#  'scrapy.downloadermiddlewares.redirect.RedirectMiddleware',
#  'scrapy.downloadermiddlewares.cookies.CookiesMiddleware',
#  'scrapy.downloadermiddlewares.httpproxy.HttpProxyMiddleware',
#  'scrapy.downloadermiddlewares.stats.DownloaderStats']
# 2022-10-19 20:19:28 [scrapy.middleware] INFO: Enabled spider middlewares:
# ['scrapy.spidermiddlewares.httperror.HttpErrorMiddleware',
#  'scrapy.spidermiddlewares.offsite.OffsiteMiddleware',
#  'scrapy.spidermiddlewares.referer.RefererMiddleware',
#  'scrapy.spidermiddlewares.urllength.UrlLengthMiddleware',
#  'scrapy.spidermiddlewares.depth.DepthMiddleware']
# 2022-10-19 20:19:28 [scrapy.middleware] INFO: Enabled item pipelines:
# []
# 2022-10-19 20:19:28 [scrapy.core.engine] INFO: Spider opened
# 2022-10-19 20:19:29 [scrapy.extensions.logstats] INFO: Crawled 0 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2022-10-19 20:19:29 [scrapy.extensions.telnet] INFO: Telnet console listening on 127.0.0.1:6023
# 2022-10-19 20:19:29 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://sofifa.com/robots.txt> (referer: None)
# 2022-10-19 20:19:29 [filelock] DEBUG: Attempting to acquire lock 2177334684936 on C:\Users\MILU\PycharmProjects\pythonProject\lib\site-packages\tldextract\.suffix_cache/publicsuffix.org-tlds\de84b5ca2167d4c83e38fb162f2e8738.tldextract.json.lock
# 2022-10-19 20:19:29 [filelock] DEBUG: Lock 2177334684936 acquired on C:\Users\MILU\PycharmProjects\pythonProject\lib\site-packages\tldextract\.suffix_cache/publicsuffix.org-tlds\de84b5ca2167d4c83e38fb162f2e8738.tldextract.json.lock
# 2022-10-19 20:19:29 [filelock] DEBUG: Attempting to release lock 2177334684936 on C:\Users\MILU\PycharmProjects\pythonProject\lib\site-packages\tldextract\.suffix_cache/publicsuffix.org-tlds\de84b5ca2167d4c83e38fb162f2e8738.tldextract.json.lock
# 2022-10-19 20:19:29 [filelock] DEBUG: Lock 2177334684936 released on C:\Users\MILU\PycharmProjects\pythonProject\lib\site-packages\tldextract\.suffix_cache/publicsuffix.org-tlds\de84b5ca2167d4c83e38fb162f2e8738.tldextract.json.lock
# 2022-10-19 20:19:29 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://sofifa.com/player/231747> (referer: None)
# 2022-10-19 20:19:29 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/player/231747>
#
# {'id': '231747', 'name': 'Kylian Mbappé Lottin', 'primary_position': 'ST', 'positions': ['ST', 'LW'], 'age': '23', 'birth_date': '1998/Dec/20', 'height': 182, 'weight': 73, 'Overall Rating': 91, 'Potential': 95, 'Value': '€190.5M', 'Wage': '€230K', 'Preferred Foot': 'Right', 'Weak Foot': 4, 'Skill Moves': 5, 'International Reputation': 4, 'Work Rate': 'High/ Low', 'Body Type': 'Unique', 'Real Face': 'Yes', 'Release Clause': '€366.7M', 'teams': {' Paris Saint-Germain': 85, ' France': 85}, 'attacking': {'Crossing': 78, 'Finishing': 93, 'HeadingAccuracy': 72, 'ShortPassing': 85, 'Volleys': 83}, 'skill': {'Dribbling': 93, 'Curve': 80, 'FKAccuracy': 69, 'LongPassing': 71, 'BallControl': 91}, 'movement': {'Acceleration': 97, 'SprintSpeed': 97, 'Agility': 93, 'Reactions': 93, 'Balance': 81}, 'power': {'ShotPower': 88, 'Jumping': 77, 'Stamina': 87, 'Strength': 76, 'LongShots': 82}, 'mentality': {'Aggression': 64, 'Interceptions': 38, 'Positioning': 92, 'Vision': 83, 'Penalties': 80, 'Composure': 88}, 'defending': {'DefensiveAwareness': 26, 'StandingTackle': 34, 'SlidingTackle': 32}, 'goalkeeping': {'GKDiving': 13, 'GKHandling': 5, 'GKKicking': 7, 'GKPositioning': 11, 'GKReflexes': 6}, 'player_traits': ['Solid Player', 'Flair', 'Speed Dribbler (AI)', 'Outside Foot Shot', 'Technical Dribbler (AI)'], 'player_specialities': ['#Speedster', '#Dribbler', '#Acrobat', '#Clinical Finisher', '#Complete Forward']}
# 2022-10-19 20:19:30 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://sofifa.com/player/192985> (referer: None)
# 2022-10-19 20:19:30 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/player/192985>
#
# {'id': '192985', 'name': 'Kevin De Bruyne', 'primary_position': 'CM', 'positions': ['CM', 'CAM'], 'age': '31', 'birth_date': '1991/Jun/28', 'height': 181, 'weight': 75, 'Overall Rating': 91, 'Potential': 91, 'Value': '€107.5M', 'Wage': '€350K', 'Preferred Foot': 'Right', 'Weak Foot': 5, 'Skill Moves': 4, 'International Reputation': 4, 'Work Rate': 'High/ High', 'Body Type': 'Unique', 'Real Face': 'Yes', 'Release Clause': '€198.9M', 'teams': {' Manchester City': 85, ' Belgium': 82}, 'attacking': {'Crossing': 94, 'Finishing': 85, 'HeadingAccuracy': 55, 'ShortPassing': 93, 'Volleys': 83}, 'skill': {'Dribbling': 88, 'Curve': 89, 'FKAccuracy': 83, 'LongPassing': 93, 'BallControl': 90}, 'movement': {'Acceleration': 76, 'SprintSpeed': 73, 'Agility': 76, 'Reactions': 91, 'Balance': 78}, 'power': {'ShotPower': 92, 'Jumping': 63, 'Stamina': 88, 'Strength': 74, 'LongShots': 91}, 'mentality': {'Aggression': 75, 'Interceptions': 66, 'Positioning': 88, 'Vision': 94, 'Penalties': 83, 'Composure': 89}, 'defending': {'DefensiveAwareness': 68, 'StandingTackle': 65, 'SlidingTackle': 53}, 'goalkeeping': {'GKDiving': 15, 'GKHandling': 13, 'GKKicking': 5, 'GKPositioning': 10, 'GKReflexes': 13}, 'player_traits': ['Injury Prone', 'Leadership', 'Early Crosser', 'Long Passer (AI)', 'Long Shot Taker (AI)', 'Playmaker (AI)', 'Outside Foot Shot'], 'player_specialities': ['#Dribbler', '#Playmaker\xa0', '#Engine', '#Distance Shooter', '#Crosser', '#Complete Midfielder']}
# 2022-10-19 20:19:30 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://sofifa.com/player/188545> (referer: None)
# 2022-10-19 20:19:30 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/player/188545>
#
# {'id': '188545', 'name': 'Robert Lewandowski', 'primary_position': 'ST', 'positions': ['ST'], 'age': '33', 'birth_date': '1988/Aug/21', 'height': 185, 'weight': 81, 'Overall Rating': 91, 'Potential': 91, 'Value': '€84M', 'Wage': '€420K', 'Preferred Foot': 'Right', 'Weak Foot': 4, 'Skill Moves': 4, 'International Reputation': 5, 'Work Rate': 'High/ Medium', 'Body Type': 'Unique', 'Real Face': 'Yes', 'Release Clause': '€172.2M', 'teams': {' FC Barcelona': 84, ' Poland': 77}, 'attacking': {'Crossing': 71, 'Finishing': 94, 'HeadingAccuracy': 91, 'ShortPassing': 84, 'Volleys': 89}, 'skill': {'Dribbling': 85, 'Curve': 79, 'FKAccuracy': 85, 'LongPassing': 70, 'BallControl': 89}, 'movement': {'Acceleration': 76, 'SprintSpeed': 75, 'Agility': 77, 'Reactions': 93, 'Balance': 82}, 'power': {'ShotPower': 91, 'Jumping': 85, 'Stamina': 76, 'Strength': 87, 'LongShots': 84}, 'mentality': {'Aggression': 81, 'Interceptions': 49, 'Positioning': 94, 'Vision': 81, 'Penalties': 90, 'Composure': 88}, 'defending': {'DefensiveAwareness': 35, 'StandingTackle': 42, 'SlidingTackle': 19}, 'goalkeeping': {'GKDiving': 15, 'GKHandling': 6, 'GKKicking': 12, 'GKPositioning': 8, 'GKReflexes': 10}, 'player_traits': ['Solid Player', 'Finesse Shot', 'Outside Foot Shot', 'Chip Shot (AI)'], 'player_specialities': ['#Aerial Threat', '#Distance Shooter', '#Clinical Finisher', '#Complete Forward']}
# 2022-10-19 20:19:30 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://sofifa.com/player/165153> (referer: None)
# 2022-10-19 20:19:31 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/player/165153>
#
# {'id': '165153', 'name': 'Karim Benzema', 'primary_position': 'CF', 'positions': ['CF', 'ST'], 'age': '34', 'birth_date': '1987/Dec/19', 'height': 185, 'weight': 81, 'Overall Rating': 91, 'Potential': 91, 'Value': '€64M', 'Wage': '€450K', 'Preferred Foot': 'Right', 'Weak Foot': 4, 'Skill Moves': 4, 'International Reputation': 4, 'Work Rate': 'Medium/ Medium', 'Body Type': 'Normal (170-185)', 'Real Face': 'Yes', 'Release Clause': '€131.2M', 'teams': {' Real Madrid CF': 85, ' France': 85}, 'attacking': {'Crossing': 75, 'Finishing': 92, 'HeadingAccuracy': 90, 'ShortPassing': 89, 'Volleys': 88}, 'skill': {'Dribbling': 87, 'Curve': 82, 'FKAccuracy': 73, 'LongPassing': 76, 'BallControl': 91}, 'movement': {'Acceleration': 79, 'SprintSpeed': 80, 'Agility': 78, 'Reactions': 92, 'Balance': 72}, 'power': {'ShotPower': 87, 'Jumping': 79, 'Stamina': 82, 'Strength': 82, 'LongShots': 80}, 'mentality': {'Aggression': 63, 'Interceptions': 39, 'Positioning': 92, 'Vision': 89, 'Penalties': 84, 'Composure': 90}, 'defending': {'DefensiveAwareness': 43, 'StandingTackle': 24, 'SlidingTackle': 18}, 'goalkeeping': {'GKDiving': 13, 'GKHandling': 11, 'GKKicking': 5, 'GKPositioning': 5, 'GKReflexes': 7}, 'player_traits': ['Leadership', 'Finesse Shot', 'Playmaker (AI)', 'Outside Foot Shot', 'Team Player'], 'player_specialities': ['#Poacher', '#Clinical Finisher']}
# 2022-10-19 20:19:31 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://sofifa.com/player/158023> (referer: None)
# 2022-10-19 20:19:31 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/player/158023>
#
# {'id': '158023', 'name': 'Lionel Andrés Messi Cuccittini', 'primary_position': 'CAM', 'positions': ['RW'], 'age': '35', 'birth_date': '1987/Jun/24', 'height': 169, 'weight': 67, 'Overall Rating': 91, 'Potential': 91, 'Value': '€54M', 'Wage': '€195K', 'Preferred Foot': 'Left', 'Weak Foot': 4, 'Skill Moves': 4, 'International Reputation': 5, 'Work Rate': 'Low/ Low', 'Body Type': 'Unique', 'Real Face': 'Yes', 'Release Clause': '€99.9M', 'teams': {' Paris Saint-Germain': 85, ' Argentina': 83}, 'attacking': {'Crossing': 84, 'Finishing': 90, 'HeadingAccuracy': 70, 'ShortPassing': 91, 'Volleys': 88}, 'skill': {'Dribbling': 95, 'Curve': 93, 'FKAccuracy': 93, 'LongPassing': 90, 'BallControl': 93}, 'movement': {'Acceleration': 87, 'SprintSpeed': 76, 'Agility': 91, 'Reactions': 92, 'Balance': 95}, 'power': {'ShotPower': 86, 'Jumping': 68, 'Stamina': 70, 'Strength': 68, 'LongShots': 91}, 'mentality': {'Aggression': 44, 'Interceptions': 40, 'Positioning': 93, 'Vision': 94, 'Penalties': 75, 'Composure': 96}, 'defending': {'DefensiveAwareness': 20, 'StandingTackle': 35, 'SlidingTackle': 24}, 'goalkeeping': {'GKDiving': 6, 'GKHandling': 11, 'GKKicking': 15, 'GKPositioning': 14, 'GKReflexes': 8}, 'player_traits': ['Finesse Shot', 'Long Shot Taker (AI)', 'Playmaker (AI)', 'Outside Foot Shot', 'Chip Shot (AI)', 'Technical Dribbler (AI)'], 'player_specialities': ['#Dribbler', '#Distance Shooter', '#FK Specialist', '#Acrobat', '#Clinical Finisher', '#Complete Forward']}
# 2022-10-19 20:19:31 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://sofifa.com/player/209331> (referer: None)
# 2022-10-19 20:19:32 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/player/209331>
#
# {'id': '209331', 'name': 'Mohamed Salah Ghaly', 'primary_position': 'RW', 'positions': ['RW'], 'age': '30', 'birth_date': '1992/Jun/15', 'height': 175, 'weight': 71, 'Overall Rating': 90, 'Potential': 90, 'Value': '€115.5M', 'Wage': '€270K', 'Preferred Foot': 'Left', 'Weak Foot': 3, 'Skill Moves': 4, 'International Reputation': 4, 'Work Rate': 'High/ Medium', 'Body Type': 'Unique', 'Real Face': 'Yes', 'Release Clause': '€213.7M', 'teams': {' Liverpool': 85}, 'attacking': {'Crossing': 80, 'Finishing': 93, 'HeadingAccuracy': 59, 'ShortPassing': 84, 'Volleys': 84}, 'skill': {'Dribbling': 90, 'Curve': 84, 'FKAccuracy': 69, 'LongPassing': 77, 'BallControl': 88}, 'movement': {'Acceleration': 89, 'SprintSpeed': 91, 'Agility': 90, 'Reactions': 93, 'Balance': 91}, 'power': {'ShotPower': 83, 'Jumping': 69, 'Stamina': 87, 'Strength': 75, 'LongShots': 85}, 'mentality': {'Aggression': 63, 'Interceptions': 55, 'Positioning': 92, 'Vision': 85, 'Penalties': 86, 'Composure': 92}, 'defending': {'DefensiveAwareness': 38, 'StandingTackle': 43, 'SlidingTackle': 41}, 'goalkeeping': {'GKDiving': 14, 'GKHandling': 14, 'GKKicking': 9, 'GKPositioning': 11, 'GKReflexes': 14}, 'player_traits': ['Finesse Shot', 'Long Shot Taker (AI)', 'Speed Dribbler (AI)', 'Outside Foot Shot', 'Chip Shot (AI)'], 'player_specialities': ['#Speedster', '#Dribbler', '#Acrobat', '#Clinical Finisher', '#Complete Forward']}
# 2022-10-19 20:19:32 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://sofifa.com/player/203376> (referer: None)
# 2022-10-19 20:19:32 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/player/203376>
#
# {'id': '203376', 'name': 'Virgil van Dijk', 'primary_position': 'CB', 'positions': ['CB'], 'age': '30', 'birth_date': '1991/Jul/8', 'height': 193, 'weight': 92, 'Overall Rating': 90, 'Potential': 90, 'Value': '€98M', 'Wage': '€230K', 'Preferred Foot': 'Right', 'Weak Foot': 3, 'Skill Moves': 2, 'International Reputation': 4, 'Work Rate': 'Medium/ High', 'Body Type': 'Unique', 'Real Face': 'Yes', 'Release Clause': '€181.3M', 'teams': {' Liverpool': 85, ' Netherlands': 82}, 'attacking': {'Crossing': 53, 'Finishing': 52, 'HeadingAccuracy': 87, 'ShortPassing': 79, 'Volleys': 45}, 'skill': {'Dribbling': 70, 'Curve': 60, 'FKAccuracy': 70, 'LongPassing': 86, 'BallControl': 76}, 'movement': {'Acceleration': 68, 'SprintSpeed': 91, 'Agility': 61, 'Reactions': 89, 'Balance': 53}, 'power': {'ShotPower': 81, 'Jumping': 88, 'Stamina': 74, 'Strength': 93, 'LongShots': 64}, 'mentality': {'Aggression': 85, 'Interceptions': 90, 'Positioning': 47, 'Vision': 65, 'Penalties': 62, 'Composure': 90}, 'defending': {'DefensiveAwareness': 92, 'StandingTackle': 92, 'SlidingTackle': 86}, 'goalkeeping': {'GKDiving': 13, 'GKHandling': 10, 'GKKicking': 13, 'GKPositioning': 11, 'GKReflexes': 11}, 'player_traits': ['Leadership', 'Long Passer (AI)', 'Power Header'], 'player_specialities': ['#Tackling\xa0', '#Tactician\xa0', '#Strength', '#Complete Defender']}
# 2022-10-19 20:19:32 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://sofifa.com/player/192119> (referer: None)
# 2022-10-19 20:19:32 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/player/192119>
#
# {'id': '192119', 'name': 'Thibaut Nicolas Marc Courtois', 'primary_position': 'GK', 'positions': ['GK'], 'age': '30', 'birth_date': '1992/May/11', 'height': 199, 'weight': 96, 'Overall Rating': 90, 'Potential': 91, 'Value': '€90M', 'Wage': '€250K', 'Preferred Foot': 'Left', 'Weak Foot': 3, 'Skill Moves': 1, 'International Reputation': 4, 'Work Rate': 'Medium/ Medium', 'Body Type': 'Unique', 'Real Face': 'Yes', 'Release Clause': '€191.3M', 'teams': {' Real Madrid CF': 85, ' Belgium': 82}, 'attacking': {'Crossing': 14, 'Finishing': 14, 'HeadingAccuracy': 13, 'ShortPassing': 33, 'Volleys': 12}, 'skill': {'Dribbling': 13, 'Curve': 19, 'FKAccuracy': 20, 'LongPassing': 35, 'BallControl': 23}, 'movement': {'Acceleration': 42, 'SprintSpeed': 52, 'Agility': 63, 'Reactions': 84, 'Balance': 45}, 'power': {'ShotPower': 56, 'Jumping': 68, 'Stamina': 38, 'Strength': 70, 'LongShots': 17}, 'mentality': {'Aggression': 23, 'Interceptions': 15, 'Positioning': 13, 'Vision': 44, 'Penalties': 27, 'Composure': 66}, 'defending': {'DefensiveAwareness': 20, 'StandingTackle': 18, 'SlidingTackle': 16}, 'goalkeeping': {'GKDiving': 84, 'GKHandling': 89, 'GKKicking': 75, 'GKPositioning': 89, 'GKReflexes': 90}, 'player_traits': ['GK Long Throw', 'Comes For Crosses'], 'player_specialities': []}
# 2022-10-19 20:19:33 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://sofifa.com/player/167495> (referer: None)
# 2022-10-19 20:19:33 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/player/167495>
#
# {'id': '167495', 'name': 'Manuel Peter Neuer', 'primary_position': 'GK', 'positions': ['GK'], 'age': '36', 'birth_date': '1986/Mar/27', 'height': 193, 'weight': 93, 'Overall Rating': 90, 'Potential': 90, 'Value': '€13.5M', 'Wage': '€72K', 'Preferred Foot': 'Right', 'Weak Foot': 4, 'Skill Moves': 1, 'International Reputation': 5, 'Work Rate': 'Medium/ Medium', 'Body Type': 'Unique', 'Real Face': 'Yes', 'Release Clause': '€22.3M', 'teams': {' FC Bayern München': 84, ' Germany': 85}, 'attacking': {'Crossing': 15, 'Finishing': 13, 'HeadingAccuracy': 25, 'ShortPassing': 60, 'Volleys': 11}, 'skill': {'Dribbling': 30, 'Curve': 14, 'FKAccuracy': 11, 'LongPassing': 68, 'BallControl': 46}, 'movement': {'Acceleration': 54, 'SprintSpeed': 60, 'Agility': 51, 'Reactions': 87, 'Balance': 35}, 'power': {'ShotPower': 68, 'Jumping': 77, 'Stamina': 43, 'Strength': 80, 'LongShots': 16}, 'mentality': {'Aggression': 29, 'Interceptions': 30, 'Positioning': 12, 'Vision': 70, 'Penalties': 47, 'Composure': 70}, 'defending': {'DefensiveAwareness': 17, 'StandingTackle': 10, 'SlidingTackle': 11}, 'goalkeeping': {'GKDiving': 87, 'GKHandling': 88, 'GKKicking': 91, 'GKPositioning': 91, 'GKReflexes': 88}, 'player_traits': ['Leadership', 'GK Long Throw', 'Rushes Out Of Goal', 'Comes For Crosses'], 'player_specialities': []}
# 2022-10-19 20:19:33 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://sofifa.com/player/20801> (referer: None)
# 2022-10-19 20:19:33 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/player/20801>
#
# {'id': '20801', 'name': 'Cristiano Ronaldo dos Santos Aveiro', 'primary_position': 'ST', 'positions': ['ST'], 'age': '37', 'birth_date': '1985/Feb/5', 'height': 187, 'weight': 83, 'Overall Rating': 90, 'Potential': 90, 'Value': '€41M', 'Wage': '€220K', 'Preferred Foot': 'Right', 'Weak Foot': 4, 'Skill Moves': 5, 'International Reputation': 5, 'Work Rate': 'High/ Low', 'Body Type': 'Unique', 'Real Face': 'Yes', 'Release Clause': '€77.9M', 'teams': {' Manchester United': 82, ' Portugal': 83}, 'attacking': {'Crossing': 80, 'Finishing': 93, 'HeadingAccuracy': 90, 'ShortPassing': 80, 'Volleys': 86}, 'skill': {'Dribbling': 85, 'Curve': 81, 'FKAccuracy': 79, 'LongPassing': 75, 'BallControl': 88}, 'movement': {'Acceleration': 79, 'SprintSpeed': 83, 'Agility': 77, 'Reactions': 94, 'Balance': 67}, 'power': {'ShotPower': 93, 'Jumping': 95, 'Stamina': 76, 'Strength': 77, 'LongShots': 90}, 'mentality': {'Aggression': 63, 'Interceptions': 29, 'Positioning': 95, 'Vision': 76, 'Penalties': 90, 'Composure': 95}, 'defending': {'DefensiveAwareness': 24, 'StandingTackle': 32, 'SlidingTackle': 24}, 'goalkeeping': {'GKDiving': 7, 'GKHandling': 11, 'GKKicking': 15, 'GKPositioning': 14, 'GKReflexes': 11}, 'player_traits': ['Power Free-Kick', 'Flair', 'Long Shot Taker (AI)', 'Outside Foot Shot'], 'player_specialities': ['#Aerial Threat', '#Distance Shooter', '#Clinical Finisher', '#Complete Forward']}
# 2022-10-19 20:19:34 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://sofifa.com/player/215914> (referer: None)
# 2022-10-19 20:19:34 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/player/215914>
#
# {'id': '215914', 'name': "N'Golo Kanté", 'primary_position': 'CDM', 'positions': ['CDM', 'CM'], 'age': '31', 'birth_date': '1991/Mar/29', 'height': 168, 'weight': 70, 'Overall Rating': 89, 'Potential': 89, 'Value': '€72M', 'Wage': '€220K', 'Preferred Foot': 'Right', 'Weak Foot': 3, 'Skill Moves': 2, 'International Reputation': 4, 'Work Rate': 'Medium/ High', 'Body Type': 'Unique', 'Real Face': 'Yes', 'Release Clause': '€133.2M', 'teams': {' Chelsea': 84, ' France': 85}, 'attacking': {'Crossing': 68, 'Finishing': 65, 'HeadingAccuracy': 54, 'ShortPassing': 82, 'Volleys': 56}, 'skill': {'Dribbling': 78, 'Curve': 49, 'FKAccuracy': 49, 'LongPassing': 76, 'BallControl': 81}, 'movement': {'Acceleration': 77, 'SprintSpeed': 68, 'Agility': 78, 'Reactions': 93, 'Balance': 92}, 'power': {'ShotPower': 71, 'Jumping': 75, 'Stamina': 95, 'Strength': 72, 'LongShots': 65}, 'mentality': {'Aggression': 93, 'Interceptions': 91, 'Positioning': 72, 'Vision': 77, 'Penalties': 54, 'Composure': 84}, 'defending': {'DefensiveAwareness': 90, 'StandingTackle': 93, 'SlidingTackle': 86}, 'goalkeeping': {'GKDiving': 15, 'GKHandling': 12, 'GKKicking': 10, 'GKPositioning': 7, 'GKReflexes': 10}, 'player_traits': ['Injury Prone', 'Leadership'], 'player_specialities': ['#Tackling\xa0', '#Tactician\xa0']}
# 2022-10-19 20:19:34 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://sofifa.com/player/212831> (referer: None)
# 2022-10-19 20:19:34 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/player/212831>
#
# {'id': '212831', 'name': 'Alisson Ramsés Becker', 'primary_position': 'GK', 'positions': ['GK'], 'age': '29', 'birth_date': '1992/Oct/2', 'height': 191, 'weight': 91, 'Overall Rating': 89, 'Potential': 90, 'Value': '€79M', 'Wage': '€190K', 'Preferred Foot': 'Right', 'Weak Foot': 3, 'Skill Moves': 1, 'International Reputation': 3, 'Work Rate': 'Medium/ Medium', 'Body Type': 'Unique', 'Real Face': 'Yes', 'Release Clause': '€152.1M', 'teams': {' Liverpool': 85}, 'attacking': {'Crossing': 17, 'Finishing': 13, 'HeadingAccuracy': 29, 'ShortPassing': 60, 'Volleys': 20}, 'skill': {'Dribbling': 27, 'Curve': 19, 'FKAccuracy': 18, 'LongPassing': 58, 'BallControl': 40}, 'movement': {'Acceleration': 58, 'SprintSpeed': 49, 'Agility': 40, 'Reactions': 87, 'Balance': 37}, 'power': {'ShotPower': 64, 'Jumping': 52, 'Stamina': 32, 'Strength': 78, 'LongShots': 14}, 'mentality': {'Aggression': 27, 'Interceptions': 11, 'Positioning': 13, 'Vision': 66, 'Penalties': 23, 'Composure': 68}, 'defending': {'DefensiveAwareness': 15, 'StandingTackle': 19, 'SlidingTackle': 16}, 'goalkeeping': {'GKDiving': 86, 'GKHandling': 85, 'GKKicking': 85, 'GKPositioning': 90, 'GKReflexes': 89}, 'player_traits': ['GK Long Throw', 'Rushes Out Of Goal', 'Comes For Crosses'], 'player_specialities': []}
# 2022-10-19 20:19:34 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://sofifa.com/player/212622> (referer: None)
# 2022-10-19 20:19:35 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/player/212622>
#
# {'id': '212622', 'name': 'Joshua Walter Kimmich', 'primary_position': 'CDM', 'positions': ['CDM', 'RB'], 'age': '27', 'birth_date': '1995/Feb/8', 'height': 177, 'weight': 75, 'Overall Rating': 89, 'Potential': 90, 'Value': '€105.5M', 'Wage': '€130K', 'Preferred Foot': 'Right', 'Weak Foot': 4, 'Skill Moves': 3, 'International Reputation': 4, 'Work Rate': 'High/ Medium', 'Body Type': 'Normal (170-185)', 'Real Face': 'Yes', 'Release Clause': '€182M', 'teams': {' FC Bayern München': 84, ' Germany': 85}, 'attacking': {'Crossing': 91, 'Finishing': 68, 'HeadingAccuracy': 72, 'ShortPassing': 87, 'Volleys': 69}, 'skill': {'Dribbling': 82, 'Curve': 85, 'FKAccuracy': 69, 'LongPassing': 90, 'BallControl': 85}, 'movement': {'Acceleration': 77, 'SprintSpeed': 60, 'Agility': 84, 'Reactions': 88, 'Balance': 84}, 'power': {'ShotPower': 78, 'Jumping': 79, 'Stamina': 94, 'Strength': 68, 'LongShots': 83}, 'mentality': {'Aggression': 89, 'Interceptions': 84, 'Positioning': 80, 'Vision': 85, 'Penalties': 44, 'Composure': 85}, 'defending': {'DefensiveAwareness': 85, 'StandingTackle': 85, 'SlidingTackle': 78}, 'goalkeeping': {'GKDiving': 8, 'GKHandling': 15, 'GKKicking': 7, 'GKPositioning': 15, 'GKReflexes': 15}, 'player_traits': ['Leadership', 'Long Passer (AI)', 'Playmaker (AI)'], 'player_specialities': ['#Crosser']}
# 2022-10-19 20:19:35 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://sofifa.com/player/210257> (referer: None)
# 2022-10-19 20:19:35 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/player/210257>
#
# {'id': '210257', 'name': 'Ederson Santana de Moraes', 'primary_position': 'GK', 'positions': ['GK'], 'age': '28', 'birth_date': '1993/Aug/17', 'height': 188, 'weight': 86, 'Overall Rating': 89, 'Potential': 91, 'Value': '€88M', 'Wage': '€210K', 'Preferred Foot': 'Left', 'Weak Foot': 3, 'Skill Moves': 1, 'International Reputation': 3, 'Work Rate': 'Medium/ Medium', 'Body Type': 'Unique', 'Real Face': 'Yes', 'Release Clause': '€169.4M', 'teams': {' Manchester City': 85}, 'attacking': {'Crossing': 20, 'Finishing': 14, 'HeadingAccuracy': 14, 'ShortPassing': 61, 'Volleys': 18}, 'skill': {'Dribbling': 23, 'Curve': 15, 'FKAccuracy': 20, 'LongPassing': 66, 'BallControl': 40}, 'movement': {'Acceleration': 64, 'SprintSpeed': 63, 'Agility': 60, 'Reactions': 88, 'Balance': 48}, 'power': {'ShotPower': 70, 'Jumping': 66, 'Stamina': 41, 'Strength': 78, 'LongShots': 18}, 'mentality': {'Aggression': 38, 'Interceptions': 27, 'Positioning': 20, 'Vision': 70, 'Penalties': 51, 'Composure': 70}, 'defending': {'DefensiveAwareness': 29, 'StandingTackle': 15, 'SlidingTackle': 8}, 'goalkeeping': {'GKDiving': 87, 'GKHandling': 82, 'GKKicking': 93, 'GKPositioning': 88, 'GKReflexes': 87}, 'player_traits': ['Long Passer (AI)', 'Rushes Out Of Goal', 'Comes For Crosses'], 'player_specialities': []}
# 2022-10-19 20:19:35 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://sofifa.com/player/208722> (referer: None)
# 2022-10-19 20:19:35 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/player/208722>
#
# {'id': '208722', 'name': 'Sadio Mané', 'primary_position': 'LM', 'positions': ['LM', 'CF'], 'age': '30', 'birth_date': '1992/Apr/10', 'height': 174, 'weight': 69, 'Overall Rating': 89, 'Potential': 89, 'Value': '€99.5M', 'Wage': '€145K', 'Preferred Foot': 'Right', 'Weak Foot': 4, 'Skill Moves': 4, 'International Reputation': 4, 'Work Rate': 'High/ Medium', 'Body Type': 'Unique', 'Real Face': 'Yes', 'Release Clause': '€164.2M', 'teams': {' FC Bayern München': 84}, 'attacking': {'Crossing': 78, 'Finishing': 86, 'HeadingAccuracy': 84, 'ShortPassing': 84, 'Volleys': 75}, 'skill': {'Dribbling': 88, 'Curve': 77, 'FKAccuracy': 64, 'LongPassing': 71, 'BallControl': 86}, 'movement': {'Acceleration': 91, 'SprintSpeed': 90, 'Agility': 93, 'Reactions': 91, 'Balance': 88}, 'power': {'ShotPower': 83, 'Jumping': 87, 'Stamina': 85, 'Strength': 72, 'LongShots': 78}, 'mentality': {'Aggression': 75, 'Interceptions': 35, 'Positioning': 90, 'Vision': 84, 'Penalties': 75, 'Composure': 84}, 'defending': {'DefensiveAwareness': 42, 'StandingTackle': 42, 'SlidingTackle': 38}, 'goalkeeping': {'GKDiving': 10, 'GKHandling': 10, 'GKKicking': 15, 'GKPositioning': 7, 'GKReflexes': 14}, 'player_traits': ['Flair', 'Speed Dribbler (AI)', 'Team Player'], 'player_specialities': ['#Speedster', '#Dribbler', '#Acrobat']}
# 2022-10-19 20:19:36 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://sofifa.com/player/202126> (referer: None)
# 2022-10-19 20:19:36 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/player/202126>
#
# {'id': '202126', 'name': 'Harry Kane', 'primary_position': 'ST', 'positions': ['ST'], 'age': '28', 'birth_date': '1993/Jul/28', 'height': 188, 'weight': 89, 'Overall Rating': 89, 'Potential': 89, 'Value': '€105.5M', 'Wage': '€240K', 'Preferred Foot': 'Right', 'Weak Foot': 5, 'Skill Moves': 3, 'International Reputation': 4, 'Work Rate': 'High/ High', 'Body Type': 'Unique', 'Real Face': 'Yes', 'Release Clause': '€200.5M', 'teams': {' Tottenham Hotspur': 82, ' England': 84}, 'attacking': {'Crossing': 80, 'Finishing': 93, 'HeadingAccuracy': 85, 'ShortPassing': 84, 'Volleys': 87}, 'skill': {'Dribbling': 83, 'Curve': 82, 'FKAccuracy': 65, 'LongPassing': 85, 'BallControl': 84}, 'movement': {'Acceleration': 67, 'SprintSpeed': 69, 'Agility': 68, 'Reactions': 92, 'Balance': 71}, 'power': {'ShotPower': 92, 'Jumping': 79, 'Stamina': 83, 'Strength': 83, 'LongShots': 86}, 'mentality': {'Aggression': 80, 'Interceptions': 44, 'Positioning': 94, 'Vision': 87, 'Penalties': 92, 'Composure': 92}, 'defending': {'DefensiveAwareness': 50, 'StandingTackle': 36, 'SlidingTackle': 38}, 'goalkeeping': {'GKDiving': 8, 'GKHandling': 10, 'GKKicking': 11, 'GKPositioning': 14, 'GKReflexes': 11}, 'player_traits': ['Leadership', 'Long Passer (AI)', 'Long Shot Taker (AI)', 'Playmaker (AI)', 'Outside Foot Shot'], 'player_specialities': ['#Distance Shooter', '#Clinical Finisher']}
# 2022-10-19 20:19:36 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://sofifa.com/player/200389> (referer: None)
# 2022-10-19 20:19:36 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/player/200389>
#
# {'id': '200389', 'name': 'Jan Oblak', 'primary_position': 'GK', 'positions': ['GK'], 'age': '29', 'birth_date': '1993/Jan/7', 'height': 188, 'weight': 87, 'Overall Rating': 89, 'Potential': 91, 'Value': '€85.5M', 'Wage': '€100K', 'Preferred Foot': 'Right', 'Weak Foot': 3, 'Skill Moves': 1, 'International Reputation': 5, 'Work Rate': 'Medium/ Medium', 'Body Type': 'Unique', 'Real Face': 'Yes', 'Release Clause': '€181.7M', 'teams': {' Atlético de Madrid': 83}, 'attacking': {'Crossing': 13, 'Finishing': 11, 'HeadingAccuracy': 15, 'ShortPassing': 43, 'Volleys': 13}, 'skill': {'Dribbling': 12, 'Curve': 13, 'FKAccuracy': 14, 'LongPassing': 40, 'BallControl': 30}, 'movement': {'Acceleration': 43, 'SprintSpeed': 58, 'Agility': 65, 'Reactions': 87, 'Balance': 49}, 'power': {'ShotPower': 59, 'Jumping': 77, 'Stamina': 41, 'Strength': 78, 'LongShots': 12}, 'mentality': {'Aggression': 34, 'Interceptions': 21, 'Positioning': 11, 'Vision': 65, 'Penalties': 11, 'Composure': 68}, 'defending': {'DefensiveAwareness': 27, 'StandingTackle': 12, 'SlidingTackle': 18}, 'goalkeeping': {'GKDiving': 86, 'GKHandling': 90, 'GKKicking': 78, 'GKPositioning': 87, 'GKReflexes': 89}, 'player_traits': ['Solid Player', 'GK Long Throw', 'Comes For Crosses'], 'player_specialities': []}
# 2022-10-19 20:19:36 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://sofifa.com/player/200145> (referer: None)
# 2022-10-19 20:19:37 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/player/200145>
#
# {'id': '200145', 'name': 'Carlos Henrique Venancio Casimiro', 'primary_position': 'CDM', 'positions': ['CDM'], 'age': '30', 'birth_date': '1992/Feb/23', 'height': 185, 'weight': 84, 'Overall Rating': 89, 'Potential': 89, 'Value': '€86M', 'Wage': '€240K', 'Preferred Foot': 'Right', 'Weak Foot': 3, 'Skill Moves': 2, 'International Reputation': 3, 'Work Rate': 'Medium/ High', 'Body Type': 'Unique', 'Real Face': 'Yes', 'Release Clause': '€163.4M', 'teams': {' Manchester United': 82}, 'attacking': {'Crossing': 58, 'Finishing': 64, 'HeadingAccuracy': 79, 'ShortPassing': 84, 'Volleys': 62}, 'skill': {'Dribbling': 67, 'Curve': 62, 'FKAccuracy': 74, 'LongPassing': 83, 'BallControl': 78}, 'movement': {'Acceleration': 60, 'SprintSpeed': 66, 'Agility': 61, 'Reactions': 87, 'Balance': 66}, 'power': {'ShotPower': 88, 'Jumping': 85, 'Stamina': 90, 'Strength': 90, 'LongShots': 81}, 'mentality': {'Aggression': 91, 'Interceptions': 88, 'Positioning': 75, 'Vision': 75, 'Penalties': 66, 'Composure': 84}, 'defending': {'DefensiveAwareness': 87, 'StandingTackle': 88, 'SlidingTackle': 87}, 'goalkeeping': {'GKDiving': 13, 'GKHandling': 14, 'GKKicking': 16, 'GKPositioning': 12, 'GKReflexes': 12}, 'player_traits': ['Power Free-Kick', 'Dives Into Tackles (AI)', 'Long Shot Taker (AI)', 'Team Player'], 'player_specialities': ['#Tackling\xa0', '#Tactician\xa0', '#Strength', '#Complete Defender']}
# 2022-10-19 20:19:37 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://sofifa.com/player/200104> (referer: None)
# 2022-10-19 20:19:37 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/player/200104>
#
# {'id': '200104', 'name': '\uc190\ud765\ubbfc \u5b59\u5174\u615c', 'primary_position': 'LW', 'positions': ['LW', 'LM'], 'age': '29', 'birth_date': '1992/Jul/8', 'height': 183, 'weight': 78, 'Overall Rating': 89, 'Potential': 89, 'Value': '€101M', 'Wage': '€240K', 'Preferred Foot': 'Right', 'Weak Foot': 5, 'Skill Moves': 4, 'International Reputation': 4, 'Work Rate': 'High/ Medium', 'Body Type': 'Unique', 'Real Face': 'Yes', 'Release Clause': '€191.9M', 'teams': {' Tottenham Hotspur': 82}, 'attacking': {'Crossing': 83, 'Finishing': 91, 'HeadingAccuracy': 68, 'ShortPassing': 84, 'Volleys': 79}, 'skill': {'Dribbling': 87, 'Curve': 85, 'FKAccuracy': 74, 'LongPassing': 74, 'BallControl': 84}, 'movement': {'Acceleration': 85, 'SprintSpeed': 90, 'Agility': 85, 'Reactions': 91, 'Balance': 76}, 'power': {'ShotPower': 88, 'Jumping': 60, 'Stamina': 88, 'Strength': 64, 'LongShots': 89}, 'mentality': {'Aggression': 62, 'Interceptions': 39, 'Positioning': 91, 'Vision': 84, 'Penalties': 73, 'Composure': 89}, 'defending': {'DefensiveAwareness': 47, 'StandingTackle': 34, 'SlidingTackle': 33}, 'goalkeeping': {'GKDiving': 11, 'GKHandling': 13, 'GKKicking': 13, 'GKPositioning': 6, 'GKReflexes': 10}, 'player_traits': ['Solid Player', 'Finesse Shot', 'Long Shot Taker (AI)', 'Speed Dribbler (AI)', 'Team Player'], 'player_specialities': ['#Dribbler', '#Distance Shooter', '#Clinical Finisher', '#Complete Forward']}
# 2022-10-19 20:19:37 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://sofifa.com/player/190871> (referer: None)
# 2022-10-19 20:19:37 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/player/190871>
#
# {'id': '190871', 'name': 'Neymar da Silva Santos Júnior', 'primary_position': 'LW', 'positions': ['LW'], 'age': '30', 'birth_date': '1992/Feb/5', 'height': 175, 'weight': 68, 'Overall Rating': 89, 'Potential': 89, 'Value': '€99.5M', 'Wage': '€200K', 'Preferred Foot': 'Right', 'Weak Foot': 5, 'Skill Moves': 5, 'International Reputation': 5, 'Work Rate': 'High/ Medium', 'Body Type': 'Unique', 'Real Face': 'Yes', 'Release Clause': '€184.1M', 'teams': {' Paris Saint-Germain': 85}, 'attacking': {'Crossing': 84, 'Finishing': 83, 'HeadingAccuracy': 63, 'ShortPassing': 85, 'Volleys': 86}, 'skill': {'Dribbling': 95, 'Curve': 88, 'FKAccuracy': 87, 'LongPassing': 81, 'BallControl': 94}, 'movement': {'Acceleration': 88, 'SprintSpeed': 86, 'Agility': 93, 'Reactions': 88, 'Balance': 82}, 'power': {'ShotPower': 79, 'Jumping': 62, 'Stamina': 79, 'Strength': 52, 'LongShots': 81}, 'mentality': {'Aggression': 63, 'Interceptions': 37, 'Positioning': 86, 'Vision': 89, 'Penalties': 91, 'Composure': 93}, 'defending': {'DefensiveAwareness': 35, 'StandingTackle': 32, 'SlidingTackle': 29}, 'goalkeeping': {'GKDiving': 9, 'GKHandling': 9, 'GKKicking': 15, 'GKPositioning': 15, 'GKReflexes': 11}, 'player_traits': ['Injury Prone', 'Flair', 'Speed Dribbler (AI)', 'Playmaker (AI)', 'Outside Foot Shot', 'Technical Dribbler (AI)'], 'player_specialities': ['#Dribbler', '#FK Specialist', '#Acrobat']}
# 2022-10-19 20:19:38 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://sofifa.com/player/239818> (referer: None)
# 2022-10-19 20:19:38 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/player/239818>
#
# {'id': '239818', 'name': 'Rúben dos Santos Gato Alves Dias', 'primary_position': 'CB', 'positions': ['CB'], 'age': '25', 'birth_date': '1997/May/14', 'height': 187, 'weight': 82, 'Overall Rating': 88, 'Potential': 91, 'Value': '€107.5M', 'Wage': '€230K', 'Preferred Foot': 'Right', 'Weak Foot': 4, 'Skill Moves': 2, 'International Reputation': 3, 'Work Rate': 'Medium/ High', 'Body Type': 'Normal (185+)', 'Real Face': 'Yes', 'Release Clause': '€206.9M', 'teams': {' Manchester City': 85, ' Portugal': 83}, 'attacking': {'Crossing': 54, 'Finishing': 29, 'HeadingAccuracy': 87, 'ShortPassing': 82, 'Volleys': 32}, 'skill': {'Dribbling': 64, 'Curve': 46, 'FKAccuracy': 48, 'LongPassing': 76, 'BallControl': 74}, 'movement': {'Acceleration': 57, 'SprintSpeed': 67, 'Agility': 60, 'Reactions': 89, 'Balance': 56}, 'power': {'ShotPower': 74, 'Jumping': 78, 'Stamina': 83, 'Strength': 89, 'LongShots': 26}, 'mentality': {'Aggression': 92, 'Interceptions': 85, 'Positioning': 39, 'Vision': 51, 'Penalties': 45, 'Composure': 81}, 'defending': {'DefensiveAwareness': 90, 'StandingTackle': 89, 'SlidingTackle': 85}, 'goalkeeping': {'GKDiving': 7, 'GKHandling': 8, 'GKKicking': 13, 'GKPositioning': 7, 'GKReflexes': 12}, 'player_traits': ['Leadership', 'Power Header'], 'player_specialities': ['#Tackling\xa0']}
# 2022-10-19 20:19:38 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://sofifa.com/player/239085> (referer: None)
# 2022-10-19 20:19:38 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/player/239085>
#
# {'id': '239085', 'name': 'Erling Braut Haaland', 'primary_position': 'ST', 'positions': ['ST'], 'age': '21', 'birth_date': '2000/Jul/21', 'height': 195, 'weight': 94, 'Overall Rating': 88, 'Potential': 94, 'Value': '€148M', 'Wage': '€220K', 'Preferred Foot': 'Left', 'Weak Foot': 3, 'Skill Moves': 3, 'International Reputation': 4, 'Work Rate': 'High/ Medium', 'Body Type': 'Unique', 'Real Face': 'Yes', 'Release Clause': '€303.4M', 'teams': {' Manchester City': 85, ' Norway': 76}, 'attacking': {'Crossing': 47, 'Finishing': 94, 'HeadingAccuracy': 79, 'ShortPassing': 74, 'Volleys': 88}, 'skill': {'Dribbling': 78, 'Curve': 77, 'FKAccuracy': 62, 'LongPassing': 53, 'BallControl': 82}, 'movement': {'Acceleration': 82, 'SprintSpeed': 94, 'Agility': 76, 'Reactions': 88, 'Balance': 72}, 'power': {'ShotPower': 94, 'Jumping': 74, 'Stamina': 81, 'Strength': 93, 'LongShots': 87}, 'mentality': {'Aggression': 85, 'Interceptions': 43, 'Positioning': 89, 'Vision': 74, 'Penalties': 76, 'Composure': 85}, 'defending': {'DefensiveAwareness': 44, 'StandingTackle': 53, 'SlidingTackle': 29}, 'goalkeeping': {'GKDiving': 7, 'GKHandling': 14, 'GKKicking': 13, 'GKPositioning': 11, 'GKReflexes': 7}, 'player_traits': ['Injury Prone', 'Speed Dribbler (AI)', 'Power Header'], 'player_specialities': ['#Aerial Threat', '#Distance Shooter', '#Strength', '#Clinical Finisher', '#Complete Forward']}
# 2022-10-19 20:19:38 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://sofifa.com/player/230621> (referer: None)
# 2022-10-19 20:19:39 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/player/230621>
#
# {'id': '230621', 'name': 'Gianluigi Donnarumma', 'primary_position': 'GK', 'positions': ['GK'], 'age': '23', 'birth_date': '1999/Feb/25', 'height': 196, 'weight': 90, 'Overall Rating': 88, 'Potential': 92, 'Value': '€103.5M', 'Wage': '€110K', 'Preferred Foot': 'Right', 'Weak Foot': 3, 'Skill Moves': 1, 'International Reputation': 3, 'Work Rate': 'Medium/ Medium', 'Body Type': 'Unique', 'Real Face': 'Yes', 'Release Clause': '€199.2M', 'teams': {' Paris Saint-Germain': 85, ' Italy': 84}, 'attacking': {'Crossing': 12, 'Finishing': 12, 'HeadingAccuracy': 12, 'ShortPassing': 36, 'Volleys': 8}, 'skill': {'Dribbling': 28, 'Curve': 12, 'FKAccuracy': 14, 'LongPassing': 34, 'BallControl': 30}, 'movement': {'Acceleration': 50, 'SprintSpeed': 55, 'Agility': 64, 'Reactions': 85, 'Balance': 38}, 'power': {'ShotPower': 59, 'Jumping': 72, 'Stamina': 34, 'Strength': 72, 'LongShots': 18}, 'mentality': {'Aggression': 30, 'Interceptions': 26, 'Positioning': 14, 'Vision': 60, 'Penalties': 24, 'Composure': 65}, 'defending': {'DefensiveAwareness': 20, 'StandingTackle': 14, 'SlidingTackle': 16}, 'goalkeeping': {'GKDiving': 90, 'GKHandling': 83, 'GKKicking': 79, 'GKPositioning': 85, 'GKReflexes': 89}, 'player_traits': ['Rushes Out Of Goal', 'Comes For Crosses'], 'player_specialities': []}
# 2022-10-19 20:19:39 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://sofifa.com/player/218667> (referer: None)
# 2022-10-19 20:19:39 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/player/218667>
#
# {'id': '218667', 'name': 'Bernardo Mota Veiga de Carvalho e Silva', 'primary_position': 'CAM', 'positions': ['CAM', 'CM'], 'age': '27', 'birth_date': '1994/Aug/10', 'height': 173, 'weight': 64, 'Overall Rating': 88, 'Potential': 88, 'Value': '€97.5M', 'Wage': '€260K', 'Preferred Foot': 'Left', 'Weak Foot': 3, 'Skill Moves': 4, 'International Reputation': 2, 'Work Rate': 'High/ High', 'Body Type': 'Lean (170-185)', 'Real Face': 'Yes', 'Release Clause': '€180.4M', 'teams': {' Manchester City': 85, ' Portugal': 83}, 'attacking': {'Crossing': 85, 'Finishing': 79, 'HeadingAccuracy': 51, 'ShortPassing': 89, 'Volleys': 78}, 'skill': {'Dribbling': 92, 'Curve': 85, 'FKAccuracy': 67, 'LongPassing': 77, 'BallControl': 91}, 'movement': {'Acceleration': 84, 'SprintSpeed': 71, 'Agility': 94, 'Reactions': 87, 'Balance': 92}, 'power': {'ShotPower': 79, 'Jumping': 51, 'Stamina': 93, 'Strength': 54, 'LongShots': 78}, 'mentality': {'Aggression': 75, 'Interceptions': 60, 'Positioning': 83, 'Vision': 85, 'Penalties': 68, 'Composure': 90}, 'defending': {'DefensiveAwareness': 59, 'StandingTackle': 71, 'SlidingTackle': 53}, 'goalkeeping': {'GKDiving': 9, 'GKHandling': 10, 'GKKicking': 14, 'GKPositioning': 12, 'GKReflexes': 9}, 'player_traits': ['Flair', 'Playmaker (AI)', 'Outside Foot Shot', 'Team Player', 'Technical Dribbler (AI)'], 'player_specialities': ['#Dribbler', '#Engine', '#Acrobat']}
# 2022-10-19 20:19:39 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://sofifa.com/player/210514> (referer: None)
# 2022-10-19 20:19:39 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/player/210514>
#
# {'id': '210514', 'name': 'João Pedro Cavaco Cancelo', 'primary_position': 'LB', 'positions': ['LB', 'RB'], 'age': '28', 'birth_date': '1994/May/27', 'height': 182, 'weight': 74, 'Overall Rating': 88, 'Potential': 88, 'Value': '€82.5M', 'Wage': '€250K', 'Preferred Foot': 'Right', 'Weak Foot': 4, 'Skill Moves': 4, 'International Reputation': 3, 'Work Rate': 'High/ Medium', 'Body Type': 'Unique', 'Real Face': 'Yes', 'Release Clause': '€152.6M', 'teams': {' Manchester City': 85, ' Portugal': 83}, 'attacking': {'Crossing': 88, 'Finishing': 69, 'HeadingAccuracy': 72, 'ShortPassing': 88, 'Volleys': 62}, 'skill': {'Dribbling': 86, 'Curve': 87, 'FKAccuracy': 69, 'LongPassing': 79, 'BallControl': 87}, 'movement': {'Acceleration': 86, 'SprintSpeed': 84, 'Agility': 79, 'Reactions': 85, 'Balance': 78}, 'power': {'ShotPower': 80, 'Jumping': 72, 'Stamina': 91, 'Strength': 62, 'LongShots': 79}, 'mentality': {'Aggression': 76, 'Interceptions': 82, 'Positioning': 81, 'Vision': 85, 'Penalties': 52, 'Composure': 86}, 'defending': {'DefensiveAwareness': 81, 'StandingTackle': 84, 'SlidingTackle': 80}, 'goalkeeping': {'GKDiving': 6, 'GKHandling': 9, 'GKKicking': 15, 'GKPositioning': 14, 'GKReflexes': 14}, 'player_traits': ['Early Crosser', 'Long Shot Taker (AI)', 'Outside Foot Shot', 'Technical Dribbler (AI)'], 'player_specialities': ['#Dribbler', '#Crosser']}
# 2022-10-19 20:19:40 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://sofifa.com/player/207865> (referer: None)
# 2022-10-19 20:19:40 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/player/207865>
#
# {'id': '207865', 'name': 'Marcos Aoás Corrêa', 'primary_position': 'CB', 'positions': ['CB'], 'age': '28', 'birth_date': '1994/May/14', 'height': 183, 'weight': 75, 'Overall Rating': 88, 'Potential': 90, 'Value': '€92M', 'Wage': '€170K', 'Preferred Foot': 'Right', 'Weak Foot': 3, 'Skill Moves': 3, 'International Reputation': 3, 'Work Rate': 'Medium/ High', 'Body Type': 'Normal (170-185)', 'Real Face': 'Yes', 'Release Clause': '€177.1M', 'teams': {' Paris Saint-Germain': 85}, 'attacking': {'Crossing': 68, 'Finishing': 59, 'HeadingAccuracy': 88, 'ShortPassing': 84, 'Volleys': 35}, 'skill': {'Dribbling': 69, 'Curve': 58, 'FKAccuracy': 32, 'LongPassing': 85, 'BallControl': 79}, 'movement': {'Acceleration': 77, 'SprintSpeed': 81, 'Agility': 68, 'Reactions': 88, 'Balance': 66}, 'power': {'ShotPower': 65, 'Jumping': 92, 'Stamina': 82, 'Strength': 78, 'LongShots': 45}, 'mentality': {'Aggression': 81, 'Interceptions': 89, 'Positioning': 70, 'Vision': 76, 'Penalties': 52, 'Composure': 86}, 'defending': {'DefensiveAwareness': 90, 'StandingTackle': 89, 'SlidingTackle': 89}, 'goalkeeping': {'GKDiving': 6, 'GKHandling': 6, 'GKKicking': 12, 'GKPositioning': 10, 'GKReflexes': 13}, 'player_traits': ['Power Header', 'Team Player'], 'player_specialities': ['#Tackling\xa0', '#Tactician\xa0']}
# 2022-10-19 20:19:40 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://sofifa.com/player/193041> (referer: None)
# 2022-10-19 20:19:40 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/player/193041>
#
# {'id': '193041', 'name': 'Keylor Navas Gamboa', 'primary_position': 'GK', 'positions': ['GK'], 'age': '35', 'birth_date': '1986/Dec/15', 'height': 185, 'weight': 80, 'Overall Rating': 88, 'Potential': 88, 'Value': '€10M', 'Wage': '€85K', 'Preferred Foot': 'Right', 'Weak Foot': 3, 'Skill Moves': 1, 'International Reputation': 3, 'Work Rate': 'Medium/ Medium', 'Body Type': 'Normal (185+)', 'Real Face': 'Yes', 'Release Clause': '€18.5M', 'teams': {' Paris Saint-Germain': 85}, 'attacking': {'Crossing': 11, 'Finishing': 15, 'HeadingAccuracy': 11, 'ShortPassing': 40, 'Volleys': 11}, 'skill': {'Dribbling': 24, 'Curve': 21, 'FKAccuracy': 15, 'LongPassing': 37, 'BallControl': 30}, 'movement': {'Acceleration': 54, 'SprintSpeed': 53, 'Agility': 60, 'Reactions': 85, 'Balance': 61}, 'power': {'ShotPower': 56, 'Jumping': 74, 'Stamina': 39, 'Strength': 75, 'LongShots': 13}, 'mentality': {'Aggression': 32, 'Interceptions': 22, 'Positioning': 16, 'Vision': 68, 'Penalties': 25, 'Composure': 67}, 'defending': {'DefensiveAwareness': 28, 'StandingTackle': 14, 'SlidingTackle': 14}, 'goalkeeping': {'GKDiving': 89, 'GKHandling': 84, 'GKKicking': 75, 'GKPositioning': 87, 'GKReflexes': 89}, 'player_traits': ['GK Long Throw', 'Cautious With Crosses'], 'player_specialities': []}
# 2022-10-19 20:19:40 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://sofifa.com/player/192448> (referer: None)
# 2022-10-19 20:19:40 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/player/192448>
#
# {'id': '192448', 'name': 'Marc-André ter Stegen', 'primary_position': 'GK', 'positions': ['GK'], 'age': '30', 'birth_date': '1992/Apr/30', 'height': 187, 'weight': 85, 'Overall Rating': 88, 'Potential': 89, 'Value': '€68.5M', 'Wage': '€210K', 'Preferred Foot': 'Right', 'Weak Foot': 4, 'Skill Moves': 1, 'International Reputation': 4, 'Work Rate': 'Medium/ Medium', 'Body Type': 'Unique', 'Real Face': 'Yes', 'Release Clause': '€145.6M', 'teams': {' FC Barcelona': 84, ' Germany': 85}, 'attacking': {'Crossing': 18, 'Finishing': 14, 'HeadingAccuracy': 11, 'ShortPassing': 61, 'Volleys': 14}, 'skill': {'Dribbling': 21, 'Curve': 18, 'FKAccuracy': 12, 'LongPassing': 63, 'BallControl': 30}, 'movement': {'Acceleration': 45, 'SprintSpeed': 50, 'Agility': 39, 'Reactions': 85, 'Balance': 43}, 'power': {'ShotPower': 65, 'Jumping': 79, 'Stamina': 35, 'Strength': 78, 'LongShots': 10}, 'mentality': {'Aggression': 43, 'Interceptions': 22, 'Positioning': 11, 'Vision': 70, 'Penalties': 25, 'Composure': 70}, 'defending': {'DefensiveAwareness': 25, 'StandingTackle': 13, 'SlidingTackle': 10}, 'goalkeeping': {'GKDiving': 86, 'GKHandling': 85, 'GKKicking': 87, 'GKPositioning': 85, 'GKReflexes': 90}, 'player_traits': ['Rushes Out Of Goal', 'Comes For Crosses', 'Saves with Feet'], 'player_specialities': []}
# 2022-10-19 20:19:41 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://sofifa.com/player/182521> (referer: None)
# ...
#
# {'id': '239380', 'name': 'Noa Noëll Lang', 'primary_position': 'CAM', 'positions': ['LW', 'RW', 'ST'], 'age': '23', 'birth_date': '1999/Jun/17', 'height': 179, 'weight': 69, 'Overall Rating': 78, 'Potential': 85, 'Value': '€28M', 'Wage': '€27K', 'Preferred Foot': 'Right', 'Weak Foot': 3, 'Skill Moves': 4, 'International Reputation': 1, 'Work Rate': 'High/ Medium', 'Body Type': 'Lean (170-185)', 'Real Face': 'Yes', 'Release Clause': '€44.8M', 'teams': {' Club Brugge KV': 76}, 'attacking': {'Crossing': 66, 'Finishing': 74, 'HeadingAccuracy': 48, 'ShortPassing': 77, 'Volleys': 80}, 'skill': {'Dribbling': 84, 'Curve': 69, 'FKAccuracy': 57, 'LongPassing': 67, 'BallControl': 81}, 'movement': {'Acceleration': 90, 'SprintSpeed': 82, 'Agility': 86, 'Reactions': 79, 'Balance': 87}, 'power': {'ShotPower': 72, 'Jumping': 67, 'Stamina': 74, 'Strength': 63, 'LongShots': 69}, 'mentality': {'Aggression': 70, 'Interceptions': 57, 'Positioning': 74, 'Vision': 75, 'Penalties': 71, 'Composure': 82}, 'defending': {'DefensiveAwareness': 47, 'StandingTackle': 51, 'SlidingTackle': 43}, 'goalkeeping': {'GKDiving': 13, 'GKHandling': 7, 'GKKicking': 13, 'GKPositioning': 12, 'GKReflexes': 12}, 'player_traits': ['Flair', 'Outside Foot Shot', 'Technical Dribbler (AI)'], 'player_specialities': []}
# 2022-10-19 20:24:42 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://sofifa.com/player/239207> (referer: None)
# 2022-10-19 20:24:43 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/player/239207>
#
# {'id': '239207', 'name': 'Maximiliano Gómez González', 'primary_position': 'ST', 'positions': ['ST'], 'age': '25', 'birth_date': '1996/Aug/14', 'height': 186, 'weight': 84, 'Overall Rating': 78, 'Potential': 80, 'Value': '€18M', 'Wage': '€40K', 'Preferred Foot': 'Right', 'Weak Foot': 3, 'Skill Moves': 3, 'International Reputation': 1, 'Work Rate': 'High/ Low', 'Body Type': 'Stocky (185+)', 'Real Face': 'Yes', 'Release Clause': '€35.6M', 'teams': {' Trabzonspor': 76}, 'attacking': {'Crossing': 59, 'Finishing': 80, 'HeadingAccuracy': 87, 'ShortPassing': 73, 'Volleys': 75}, 'skill': {'Dribbling': 72, 'Curve': 75, 'FKAccuracy': 57, 'LongPassing': 64, 'BallControl': 76}, 'movement': {'Acceleration': 63, 'SprintSpeed': 63, 'Agility': 66, 'Reactions': 78, 'Balance': 56}, 'power': {'ShotPower': 81, 'Jumping': 83, 'Stamina': 78, 'Strength': 88, 'LongShots': 73}, 'mentality': {'Aggression': 74, 'Interceptions': 21, 'Positioning': 82, 'Vision': 70, 'Penalties': 72, 'Composure': 80}, 'defending': {'DefensiveAwareness': 35, 'StandingTackle': 20, 'SlidingTackle': 23}, 'goalkeeping': {'GKDiving': 7, 'GKHandling': 8, 'GKKicking': 13, 'GKPositioning': 12, 'GKReflexes': 6}, 'player_traits': ['Power Header'], 'player_specialities': ['#Strength']}
# 2022-10-19 20:24:43 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://sofifa.com/player/238616> (referer: None)
# 2022-10-19 20:24:43 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/player/238616>
#
# {'id': '238616', 'name': 'Pedro Lomba Neto', 'primary_position': 'CAM', 'positions': ['LW', 'RW', 'ST'], 'age': '22', 'birth_date': '2000/Mar/9', 'height': 172, 'weight': 62, 'Overall Rating': 78, 'Potential': 85, 'Value': '€28.5M', 'Wage': '€72K', 'Preferred Foot': 'Left', 'Weak Foot': 4, 'Skill Moves': 4, 'International Reputation': 1, 'Work Rate': 'High/ Medium', 'Body Type': 'Normal (170-185)', 'Real Face': 'Yes', 'Release Clause': '€59.9M', 'teams': {' Wolverhampton Wanderers': 78}, 'attacking': {'Crossing': 70, 'Finishing': 76, 'HeadingAccuracy': 49, 'ShortPassing': 75, 'Volleys': 65}, 'skill': {'Dribbling': 83, 'Curve': 68, 'FKAccuracy': 54, 'LongPassing': 56, 'BallControl': 80}, 'movement': {'Acceleration': 86, 'SprintSpeed': 85, 'Agility': 86, 'Reactions': 75, 'Balance': 86}, 'power': {'ShotPower': 76, 'Jumping': 52, 'Stamina': 64, 'Strength': 56, 'LongShots': 74}, 'mentality': {'Aggression': 55, 'Interceptions': 41, 'Positioning': 76, 'Vision': 73, 'Penalties': 62, 'Composure': 66}, 'defending': {'DefensiveAwareness': 32, 'StandingTackle': 23, 'SlidingTackle': 17}, 'goalkeeping': {'GKDiving': 6, 'GKHandling': 13, 'GKKicking': 7, 'GKPositioning': 12, 'GKReflexes': 6}, 'player_traits': ['Speed Dribbler (AI)'], 'player_specialities': []}
# 2022-10-19 20:24:43 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://sofifa.com/player/238463> (referer: None)
# 2022-10-19 20:24:43 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/player/238463>
#
# {'id': '238463', 'name': 'Amadou Haïdara', 'primary_position': 'CM', 'positions': ['CM', 'CDM', 'RM'], 'age': '24', 'birth_date': '1998/Jan/31', 'height': 175, 'weight': 72, 'Overall Rating': 78, 'Potential': 82, 'Value': '€20M', 'Wage': '€43K', 'Preferred Foot': 'Right', 'Weak Foot': 2, 'Skill Moves': 3, 'International Reputation': 2, 'Work Rate': 'High/ Medium', 'Body Type': 'Lean (170-185)', 'Real Face': 'Yes', 'Release Clause': '€35.5M', 'teams': {' RB Leipzig': 81}, 'attacking': {'Crossing': 74, 'Finishing': 69, 'HeadingAccuracy': 50, 'ShortPassing': 80, 'Volleys': 61}, 'skill': {'Dribbling': 81, 'Curve': 75, 'FKAccuracy': 62, 'LongPassing': 75, 'BallControl': 81}, 'movement': {'Acceleration': 74, 'SprintSpeed': 66, 'Agility': 78, 'Reactions': 78, 'Balance': 76}, 'power': {'ShotPower': 77, 'Jumping': 76, 'Stamina': 81, 'Strength': 65, 'LongShots': 77}, 'mentality': {'Aggression': 69, 'Interceptions': 76, 'Positioning': 74, 'Vision': 77, 'Penalties': 62, 'Composure': 76}, 'defending': {'DefensiveAwareness': 68, 'StandingTackle': 69, 'SlidingTackle': 62}, 'goalkeeping': {'GKDiving': 7, 'GKHandling': 11, 'GKKicking': 8, 'GKPositioning': 7, 'GKReflexes': 10}, 'player_traits': ['Long Shot Taker (AI)'], 'player_specialities': []}
# 2022-10-19 20:24:44 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://sofifa.com/player/236679> (referer: None)
# 2022-10-19 20:24:44 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/player/236679>
#
# {'id': '236679', 'name': 'Óscar Melendo Jiménez', 'primary_position': 'CAM', 'positions': ['CAM', 'RM', 'CM'], 'age': '24', 'birth_date': '1997/Aug/23', 'height': 167, 'weight': 63, 'Overall Rating': 78, 'Potential': 82, 'Value': '€20M', 'Wage': '€12K', 'Preferred Foot': 'Left', 'Weak Foot': 2, 'Skill Moves': 4, 'International Reputation': 1, 'Work Rate': 'High/ Medium', 'Body Type': 'Lean (170-)', 'Real Face': 'No', 'Release Clause': '€33.5M', 'teams': {' Granada CF': 74}, 'attacking': {'Crossing': 74, 'Finishing': 65, 'HeadingAccuracy': 45, 'ShortPassing': 84, 'Volleys': 63}, 'skill': {'Dribbling': 78, 'Curve': 81, 'FKAccuracy': 50, 'LongPassing': 78, 'BallControl': 80}, 'movement': {'Acceleration': 81, 'SprintSpeed': 79, 'Agility': 86, 'Reactions': 72, 'Balance': 88}, 'power': {'ShotPower': 66, 'Jumping': 60, 'Stamina': 62, 'Strength': 53, 'LongShots': 63}, 'mentality': {'Aggression': 63, 'Interceptions': 50, 'Positioning': 75, 'Vision': 83, 'Penalties': 50, 'Composure': 70}, 'defending': {'DefensiveAwareness': 50, 'StandingTackle': 45, 'SlidingTackle': 40}, 'goalkeeping': {'GKDiving': 9, 'GKHandling': 7, 'GKKicking': 13, 'GKPositioning': 15, 'GKReflexes': 8}, 'player_traits': ['Flair', 'Playmaker (AI)', 'Technical Dribbler (AI)'], 'player_specialities': []}
# 2022-10-19 20:24:44 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://sofifa.com/player/236610> (referer: None)
# 2022-10-19 20:24:44 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/player/236610>
#
# {'id': '236610', 'name': 'Moise Bioty Kean', 'primary_position': 'ST', 'positions': ['ST', 'LW'], 'age': '22', 'birth_date': '2000/Feb/28', 'height': 182, 'weight': 72, 'Overall Rating': 78, 'Potential': 86, 'Value': '€32M', 'Wage': '€41K', 'Preferred Foot': 'Right', 'Weak Foot': 3, 'Skill Moves': 3, 'International Reputation': 2, 'Work Rate': 'High/ Medium', 'Body Type': 'Normal (170-185)', 'Real Face': 'Yes', 'teams': {' Juventus': 82, ' Italy': 84}, 'attacking': {'Crossing': 48, 'Finishing': 79, 'HeadingAccuracy': 76, 'ShortPassing': 68, 'Volleys': 71}, 'skill': {'Dribbling': 79, 'Curve': 67, 'FKAccuracy': 44, 'LongPassing': 46, 'BallControl': 76}, 'movement': {'Acceleration': 84, 'SprintSpeed': 85, 'Agility': 76, 'Reactions': 74, 'Balance': 79}, 'power': {'ShotPower': 84, 'Jumping': 76, 'Stamina': 70, 'Strength': 85, 'LongShots': 66}, 'mentality': {'Aggression': 57, 'Interceptions': 31, 'Positioning': 81, 'Vision': 58, 'Penalties': 65, 'Composure': 72}, 'defending': {'DefensiveAwareness': 40, 'StandingTackle': 36, 'SlidingTackle': 30}, 'goalkeeping': {'GKDiving': 13, 'GKHandling': 8, 'GKKicking': 10, 'GKPositioning': 7, 'GKReflexes': 9}, 'player_traits': ['Flair'], 'player_specialities': []}
# 2022-10-19 20:24:44 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://sofifa.com/player/236583> (referer: None)
# 2022-10-19 20:24:45 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/player/236583>
#
# {'id': '236583', 'name': 'Ji\u0159í Pavlenka', 'primary_position': 'GK', 'positions': ['GK'], 'age': '30', 'birth_date': '1992/Apr/14', 'height': 196, 'weight': 81, 'Overall Rating': 78, 'Potential': 78, 'Value': '€9.5M', 'Wage': '€21K', 'Preferred Foot': 'Right', 'Weak Foot': 3, 'Skill Moves': 1, 'International Reputation': 2, 'Work Rate': 'Medium/ Medium', 'Body Type': 'Normal (185+)', 'Real Face': 'Yes', 'Release Clause': '€17.1M', 'teams': {' SV Werder Bremen': 73}, 'attacking': {'Crossing': 11, 'Finishing': 16, 'HeadingAccuracy': 14, 'ShortPassing': 28, 'Volleys': 19}, 'skill': {'Dribbling': 12, 'Curve': 10, 'FKAccuracy': 14, 'LongPassing': 17, 'BallControl': 19}, 'movement': {'Acceleration': 35, 'SprintSpeed': 37, 'Agility': 39, 'Reactions': 79, 'Balance': 27}, 'power': {'ShotPower': 45, 'Jumping': 36, 'Stamina': 20, 'Strength': 68, 'LongShots': 17}, 'mentality': {'Aggression': 22, 'Interceptions': 13, 'Positioning': 14, 'Vision': 25, 'Penalties': 18, 'Composure': 39}, 'defending': {'DefensiveAwareness': 12, 'StandingTackle': 10, 'SlidingTackle': 14}, 'goalkeeping': {'GKDiving': 81, 'GKHandling': 74, 'GKKicking': 60, 'GKPositioning': 69, 'GKReflexes': 84}, 'player_traits': ['Saves with Feet'], 'player_specialities': []}
# 2022-10-19 20:24:45 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://sofifa.com/player/236499> (referer: None)
# 2022-10-19 20:24:45 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/player/236499>
#
# {'id': '236499', 'name': 'Douglas Luiz Soares de Paulo', 'primary_position': 'CM', 'positions': ['CDM', 'CM'], 'age': '24', 'birth_date': '1998/May/9', 'height': 175, 'weight': 66, 'Overall Rating': 78, 'Potential': 83, 'Value': '€19.5M', 'Wage': '€59K', 'Preferred Foot': 'Right', 'Weak Foot': 2, 'Skill Moves': 3, 'International Reputation': 2, 'Work Rate': 'High/ Medium', 'Body Type': 'Normal (170-185)', 'Real Face': 'Yes', 'Release Clause': '€38.5M', 'teams': {' Aston Villa': 79}, 'attacking': {'Crossing': 69, 'Finishing': 64, 'HeadingAccuracy': 62, 'ShortPassing': 82, 'Volleys': 58}, 'skill': {'Dribbling': 76, 'Curve': 84, 'FKAccuracy': 76, 'LongPassing': 81, 'BallControl': 83}, 'movement': {'Acceleration': 69, 'SprintSpeed': 65, 'Agility': 74, 'Reactions': 77, 'Balance': 74}, 'power': {'ShotPower': 80, 'Jumping': 66, 'Stamina': 76, 'Strength': 66, 'LongShots': 81}, 'mentality': {'Aggression': 74, 'Interceptions': 77, 'Positioning': 58, 'Vision': 79, 'Penalties': 44, 'Composure': 82}, 'defending': {'DefensiveAwareness': 75, 'StandingTackle': 75, 'SlidingTackle': 68}, 'goalkeeping': {'GKDiving': 12, 'GKHandling': 6, 'GKKicking': 13, 'GKPositioning': 10, 'GKReflexes': 7}, 'player_traits': ['Solid Player', 'Finesse Shot', 'Flair', 'Long Shot Taker (AI)', 'Playmaker (AI)'], 'player_specialities': []}
# 2022-10-19 20:24:45 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://sofifa.com/player/235619> (referer: None)
# 2022-10-19 20:24:45 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/player/235619>
#
# {'id': '235619', 'name': 'Marcus Edwards', 'primary_position': 'CAM', 'positions': ['RW', 'LW'], 'age': '23', 'birth_date': '1998/Dec/3', 'height': 168, 'weight': 65, 'Overall Rating': 78, 'Potential': 84, 'Value': '€22M', 'Wage': '€15K', 'Preferred Foot': 'Left', 'Weak Foot': 3, 'Skill Moves': 4, 'International Reputation': 1, 'Work Rate': 'High/ Low', 'Body Type': 'Normal (170-)', 'Real Face': 'Yes', 'Release Clause': '€48.4M', 'teams': {' Sporting CP': 78}, 'attacking': {'Crossing': 69, 'Finishing': 70, 'HeadingAccuracy': 37, 'ShortPassing': 73, 'Volleys': 69}, 'skill': {'Dribbling': 84, 'Curve': 76, 'FKAccuracy': 60, 'LongPassing': 60, 'BallControl': 81}, 'movement': {'Acceleration': 88, 'SprintSpeed': 82, 'Agility': 92, 'Reactions': 78, 'Balance': 92}, 'power': {'ShotPower': 70, 'Jumping': 45, 'Stamina': 71, 'Strength': 38, 'LongShots': 75}, 'mentality': {'Aggression': 43, 'Interceptions': 30, 'Positioning': 74, 'Vision': 73, 'Penalties': 58, 'Composure': 78}, 'defending': {'DefensiveAwareness': 38, 'StandingTackle': 32, 'SlidingTackle': 24}, 'goalkeeping': {'GKDiving': 7, 'GKHandling': 12, 'GKKicking': 15, 'GKPositioning': 15, 'GKReflexes': 6}, 'player_traits': ['Flair', 'Technical Dribbler (AI)'], 'player_specialities': ['#Acrobat']}
# 2022-10-19 20:24:46 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://sofifa.com/player/234612> (referer: None)
# 2022-10-19 20:24:46 [scrapy.core.scraper] DEBUG: Scraped from <200 https://sofifa.com/player/234612>
#
# {'id': '234612', 'name': 'Nanitamo Jonathan Ikoné', 'primary_position': 'LM', 'positions': ['RW', 'RM'], 'age': '24', 'birth_date': '1998/May/2', 'height': 175, 'weight': 73, 'Overall Rating': 78, 'Potential': 82, 'Value': '€20M', 'Wage': '€50K', 'Preferred Foot': 'Left', 'Weak Foot': 3, 'Skill Moves': 4, 'International Reputation': 3, 'Work Rate': 'High/ Medium', 'Body Type': 'Normal (170-185)', 'Real Face': 'Yes', 'Release Clause': '€35.5M', 'teams': {' Fiorentina': 77}, 'attacking': {'Crossing': 73, 'Finishing': 68, 'HeadingAccuracy': 39, 'ShortPassing': 73, 'Volleys': 59}, 'skill': {'Dribbling': 85, 'Curve': 78, 'FKAccuracy': 72, 'LongPassing': 64, 'BallControl': 79}, 'movement': {'Acceleration': 90, 'SprintSpeed': 89, 'Agility': 92, 'Reactions': 75, 'Balance': 82}, 'power': {'ShotPower': 75, 'Jumping': 34, 'Stamina': 72, 'Strength': 55, 'LongShots': 68}, 'mentality': {'Aggression': 65, 'Interceptions': 34, 'Positioning': 74, 'Vision': 78, 'Penalties': 70, 'Composure': 78}, 'defending': {'DefensiveAwareness': 32, 'StandingTackle': 36, 'SlidingTackle': 36}, 'goalkeeping': {'GKDiving': 9, 'GKHandling': 8, 'GKKicking': 13, 'GKPositioning': 8, 'GKReflexes': 14}, 'player_traits': ['Flair', 'Playmaker (AI)', 'Outside Foot Shot', 'Technical Dribbler (AI)'], 'player_specialities': ['#Acrobat']}
# 2022-10-19 20:24:46 [scrapy.core.engine] INFO: Closing spider (finished)
# 2022-10-19 20:24:46 [scrapy.extensions.feedexport] INFO: Stored json feed (720 items) in: dataset/players_info.json
# 2022-10-19 20:24:46 [scrapy.statscollectors] INFO: Dumping Scrapy stats:
# {'downloader/request_bytes': 181626,
#  'downloader/request_count': 721,
#  'downloader/request_method_count/GET': 721,
#  'downloader/response_bytes': 82359263,
#  'downloader/response_count': 721,
#  'downloader/response_status_count/200': 721,
#  'elapsed_time_seconds': 317.367749,
#  'feedexport/success_count/FileFeedStorage': 1,
#  'finish_reason': 'finished',
#  'finish_time': datetime.datetime(2022, 10, 19, 13, 24, 46, 418993),
#  'httpcompression/response_bytes': 320823619,
#  'httpcompression/response_count': 721,
#  'item_scraped_count': 720,
#  'log_count/DEBUG': 1448,
#  'log_count/INFO': 16,
#  'response_received_count': 721,
#  'robotstxt/request_count': 1,
#  'robotstxt/response_count': 1,
#  'robotstxt/response_status_count/200': 1,
#  'scheduler/dequeued': 720,
#  'scheduler/dequeued/memory': 720,
#  'scheduler/enqueued': 720,
#  'scheduler/enqueued/memory': 720,
#  'start_time': datetime.datetime(2022, 10, 19, 13, 19, 29, 51244)}
# 2022-10-19 20:24:46 [scrapy.core.engine] INFO: Spider closed (finished)

# %% [markdown]
# Sau khi đã có thông tin chi tiết của 720 cầu thủ, các bạn sẽ tiến hành đọc file <b>players_info.json</b> vào pandas với tên gọi <b>df_players_info</b> và kiểm tra lại với file của mình xem dữ liệu các bạn thu thập là khớp chưa. Nếu đã trùng khớp hai file thì bạn sẽ đến với bước tiền xử lý dữ liệu.

# %%
# YOUR CODE HERE
players=[]
with open('./content/players_info.json') as f:
                players = json.load(f)
df_test=pd.DataFrame(players)
with open('./dataset/players_info.json') as f:
                players = json.load(f)

df_players_info=pd.DataFrame(players)

try:
  assert_frame_equal(df_players_info, df_test)
except Exception as e:
  print(e)

# %% [markdown]
# <h2><b>Tiền xử lý dữ liệu</b></h2>
#
# <b>1)</b> Sau khi đã kiểm tra và khớp với dữ liệu từ file mình đã cung cấp, nhiệm vụ đầu tiên của các bạn trong bước tiền xử lý dữ liệu là cần phân tách các chỉ số cụ thể của mỗi cầu thủ. Như chúng ta thấy, ở mỗi cột <b>attacking, skill, movement</b> sẽ là một từ điển chứa chi tiết cụ thể từng chỉ số chi tiết ở trong đó. Do đó, chúng ta sẽ cần phân tách các từ điển này thành các cột cụ thể và nhiệm vụ khi này của bạn là hoàn thành hàm <b>split_players_info()</b> ở bên dưới rồi lưu lại vào một dataframe mới với tên <b>df_split_players_info</b>.

# %%
def split_players_info():
  players=[]
  with open('./dataset/players_info.json') as f:
                players = json.load(f)
  def Merge(dict1, dict2):
    res = {**dict1, **dict2}
    return res

  def changename(_dict_,oldname,newname):
    for i in range(len(newname)):
      try:
        _dict_[newname[i]]=_dict_.pop(oldname[i])
      except:
        1#_dict_[newname[i]]=[]
  def extenddict(_dict_,outrule=[]):
    temp=_dict_
    plus={}
    pop_items=[]
    for i in temp.keys():
      if(i in outrule):
        continue
      try :
        temp[i].keys()
        pre=temp[i]
        pop_items.append(i)
        for j in pre.keys():
          plus=Merge(plus,{j:pre[j]})
      except:
        False
    for i in pop_items:
      temp.pop(i)
    temp=Merge(temp,plus)
    return temp
  #sau khi file được update thì không cần dùng nữa 
  old_name=['id', 'name', 'primary_position', 'positions', 'age', 'birth_date',
       'height', 'weight', 'Overall Rating', 'Potential', 'Value', 'Wage',
       'Preferred Foot', 'Weak Foot', 'Skill Moves',
       'International Reputation', 'Work Rate', 'Body Type', 'Real Face',
       'Release Clause', 'teams', 'player_traits', 'player_specialities',
       'Crossing', 'Finishing', 'HeadingAccuracy', 'ShortPassing', 'Volleys',
       'Dribbling', 'Curve', 'FKAccuracy', 'LongPassing', 'BallControl',
       'Acceleration', 'SprintSpeed', 'Agility', 'Reactions', 'Balance',
       'ShotPower', 'Jumping', 'Stamina', 'Strength', 'LongShots',
       'Aggression', 'Interceptions', 'Positioning', 'Vision', 'Penalties',
       'Composure', 'DefensiveAwareness', 'StandingTackle', 'SlidingTackle',
       'GKDiving', 'GKHandling', 'GKKicking', 'GKPositioning', 'GKReflexes']

  new_name=['id', 'name', 'primary_position', 'positions', 'age', 'birth_date',
       'height', 'weight', 'Overall Rating', 'Potential', 'Value', 'Wage',
       'Preferred Foot', 'Weak Foot', 'Skill Moves',
       'International Reputation', 'Work Rate', 'Body Type', 'Real Face',
       'Release Clause', 'teams', 'player_traits', 'player_specialities',
       'Crossing', 'Finishing', 'HeadingAccuracy', 'ShortPassing', 'Volleys',
       'Dribbling', 'Curve', 'FK_Accuracy', 'Long_Passing', 'Ball_Control',
       'Acceleration', 'Sprint_Speed', 'Agility', 'Reactions', 'Balance',
       'Shot_Power', 'Jumping', 'Stamina', 'Strength', 'Long_Shots',
       'Aggression', 'Interceptions', 'Positioning', 'Vision', 'Penalties',
       'Composure', 'Defensive_Awareness', 'Standing_Tackle', 'Sliding_Tackle',
       'GK_Diving', 'GK_Handling', 'GK_Kicking', 'GK_Positioning',
       'GK_Reflexes']

  for i in range(len(players)):
    players[i]=extenddict(players[i],outrule=['teams'])
    players[i]['id']=int(players[i]['id'])
    players[i]['age']=int(players[i]['age'])
    #changename(players[i],old_name,new_name)
  df=pd.DataFrame(players)
  df_split_players_info=(df.to_json(orient = 'columns'))

  f=open('dataset/split_players_info.json', 'w')
  f.write(df_split_players_info)
  df_split_players_info=pd.read_json(df_split_players_info, encoding='utf-8-sig')
  return df_split_players_info

# %%
# TEST
df_split_players_info = split_players_info()
df_split_players_info_test = pd.read_json('./content/split_players_info.json', encoding='utf-8-sig')
try:
  assert_frame_equal(df_split_players_info.iloc[:, 23:], df_split_players_info_test.iloc[:, 23:])
except Exception as e:
  print(e)

# %% [markdown]
# <b>2)</b> Vì cột giá trị của cầu thủ (Value) và tiền lương (Wage) đang ở dạng viết tắt nên các bạn cần chuyển hai cột này về dạng số (float) bằng cách hoàn thành hàm <b>value_and_wage_to_float(col)</b>. Ví dụ, cầu thủ A có giá trị là €1M và tiền lương là €1K, hai cột này sau khi được tiền xử lý thì cầu thủ A sẽ có giá trị là 1000000.0 và tiền lương là 1000. Ngoài ra, bạn cần lưu ý kiểm tra các cột này có giá trị bị thiếu hay không, nếu có sẽ điền là 0.0 và ngược lại sẽ tiền xử lý như trên.

# %%
from pandas.core.api import isnull
# - (?<=\[): (?<=) is called a look-behind assertion and checks for an expression preceding the actual match.
# - .+?: + is just like * except that it matches one or more repititions. It is made non-greedy by ?.
# - (?=\]): (?=) is a look-ahead assertion and checks for an expression following the match w/o capturing it.

def checkmoney(i):
  if(isnull(i)):
    return 0.0
  try:
    return float(i)
  except:
    False
  money=0
  try:
    money=float(re.findall('[0-9]{1,}[\.]{0,1}[0-9]{0,}',i)[0])
  except:
    money=0
  ar=''
  try:
    ar=re.findall('(?<=[0-9]{1})[a-zA-Z]{1}',i)[0]
  except:
    ar=''
  if ar=='M' or ar=='m':
    return money*1000000
  elif ar=='K' or ar=='k' :
    return money*1000
  return money
def makecoltofloat(col):
  for i in range(len(df_split_players_info[col])):
    df_split_players_info[col][i]=checkmoney(df_split_players_info[col][i])
def value_and_wage_to_float(col):
  makecoltofloat('Value')
  makecoltofloat('Wage')
value_and_wage_to_float(True)
# Out:
# C:\Users\MILU\PycharmProjects\pythonProject\lib\site-packages\ipykernel_launcher.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
# TEST
assert df_split_players_info['Wage'].to_list()[:5] == [230000.0, 350000.0, 420000.0, 450000.0, 195000.0]
assert df_split_players_info['Wage'].to_list()[-5:] == [41000.0, 21000.0, 59000.0, 15000.0, 50000.0]
assert df_split_players_info['Value'].to_list()[:5] == [190500000.0, 107500000.0, 84000000.0, 64000000.0, 54000000.0]
assert df_split_players_info['Value'].to_list()[-5:] == [32000000.0, 9500000.0, 19500000.0, 22000000.0, 20000000.0]

# %% [markdown]
# <b>3)</b> Vì cột giá trị giải phóng hợp đồng (Release Clause) của cầu thủ đang ở dạng object, các bạn cần chuyển về dạng chuỗi và sau đó tiến hành tiền xử lý tương tự như hai cột <b>Value</b> và <b>Wage</b> ở trên bằng cách hoàn thành hàm <b>release_clause_to_float(col)</b>.

# %%
def release_clause_to_float(col):
  makecoltofloat('Release Clause')
release_clause_to_float(True)
# Out:
# C:\Users\MILU\PycharmProjects\pythonProject\lib\site-packages\ipykernel_launcher.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
# TEST
assert df_split_players_info['Release Clause'].to_list()[:5] == [366700000.0, 198900000.0, 172200000.0, 131199999.99999999, 99900000.0]
assert df_split_players_info['Release Clause'].to_list()[-5:] == [0.0, 17100000.0, 38500000.0, 48400000.0, 35500000.0]
